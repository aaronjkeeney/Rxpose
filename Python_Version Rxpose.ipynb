# %% [markdown]
# # RXposé (Version 2.0) #
#
# As of March, 2024, I greatly prefer working in Python over R. In this file, I will build a better pipeline than the version in R from last year, as well as (hopefully) incoroporate a better data source to be able to finish the original analysis. Ideally, this project will also produce a searchable database, allowing other contributors to perform future analysis.

# %% [markdown]
# ## Data Collection ##
#
# The first step is to collect better data. [This website](https://iwrp.net/) has results in PDF format going back to 1928. Since this format is not helpful for computer analysis, we need to scrape it and convert it to a .csv or similarly usable file.

# %%
# Imports for data collection

import requests
from bs4 import BeautifulSoup

import re

import numpy as np
import pandas as pd

import warnings

# %%
def download_table(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
    table = soup.find_all('table')
    
    
    if table:
        df = pd.read_html(str(table))[0]
        return df
        
    else:
        print(f"No table found on page")
        return None

# %%
df = download_table('https://iwrp.net/')
# Out:
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_9859/291072501.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
print(df.head())
print(df.size)
# Out:
#          Date                              Name        Place Nation   Gender  \
# 0  2023-12-04                    IWF Grand Prix         Doha    QAT    Males
# 1  2023-12-04                    IWF Grand Prix         Doha    QAT  Females
# 2  2023-11-15  48 th Junior World Championships  Guadalajara    MEX    Males
# 3  2023-11-15  27 th Junior World Championships  Guadalajara    MEX  Females
# 4  2023-10-20  11 th Youth Polish Championships     Biłgoraj    POL    Males
#
#   Age category
# 0       Senior
# 1       Senior
# 2       Junior
# 3       Junior
# 4     Youth 15
# 15510

# %%
print(df[df['Gender'] == 'Males'].size)
print(df[df['Gender'] == 'Females'].size)
# Out:
# 6276
# 4656

# %%
df.dtypes
# Out:
# Date            object
# Name            object
# Place           object
# Nation          object
# Gender          object
# Age category    object
# dtype: object

# %%
def is_valid_date(date_string):
    try: 
        pd.to_datetime(date_string)
        return True
    except:
        ValueError
        return False

# %%
# df['Date'] = pd.to_datetime(df['Date'])

# This throws and erro without fixing the one problematic input

# %%
valid_dates_mask = df['Date'].apply(is_valid_date)

invalid_dates = df[~valid_dates_mask]
invalid_dates
# Out:
#             Date                          Name  Place Nation Gender  \
# 2538  1979-00-00  57 th European Championships  Varna    BUL  Males
#
#      Age category
# 2538       Senior

# %%
# Quick internt search for the correct date

def replace_invalid_date(date_string):
    try: 
        pd.to_datetime(date_string)
        return date_string
    except:
        ValueError
        return '1979-05-19'
    
df['Date'] = df['Date'].apply(replace_invalid_date)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2585 entries, 0 to 2584
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2585 non-null   datetime64[ns]
#  1   Name          2585 non-null   object
#  2   Place         2583 non-null   object
#  3   Nation        2585 non-null   object
#  4   Gender        2585 non-null   object
#  5   Age category  2585 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 121.3+ KB

# %% [markdown]
# Okay, what I actually need to do for now:
#
# 1. I need to have a single dataframe with all the results, but I need the date included. I think I need to go back and get a datetime object instead of a numerical year. Then I can avoid duplicate rows, since a single lifter's total, name, and date of competition will be uniquely identifying. Not all of this data will be used in this analysis, but we want to be able to easily search for all international performances of any lifter.
#
# 2. I need to then retrieve the actual lifting information from the links. The smaller dataframe generated by importing the table(s) at each link can then be appended to the large dataframe. I NEED TO MAKE SURE THAT THE DATE AND THE WEIGHT CATEGORY ARE INCLUDED IN EACH ROW AS PART OF THIS TRANSFORMATION. This should be fairly simple. Create the data frame with the necessary columns, then populate all the scraped values as additional columns.

# %%
# Loop through the 'Name' column and follow the links

def download_links(url: str, events_list: list) -> pd.DataFrame:
    # Send GET request to URL
    response = requests.get(url)
    
    # Parse the HTML
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all links on the page to sort later
    links = soup.find_all('a')
    
    return [link for link in links]

# %%
links = download_links('https://iwrp.net/', df['Name'])
print(type(links))
# Out:
# <class 'list'>

# %%
print(links[:10])
print(len(links))
print(len(df['Name']))
# Out:
# [<a href="/">IWRP</a>, <a href="/global-statistics">Global Statistics</a>, <a href="/../"><div class="header__logo"></div></a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2752">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2753">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2748">48 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2749">27 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2746">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2747">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2745">28 th Waldemar Malak Memorial	</a>]
# 2590
# 2585

# %%
links = links[3:-2]
links[:10]
# Out:
# [<a href="/component/cwyniki/?view=contest&amp;id_zawody=2752">IWF Grand Prix</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2753">IWF Grand Prix</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2748">48 th Junior World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2749">27 th Junior World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2746">11 th Youth Polish Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2747">11 th Youth Polish Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2745">28 th Waldemar Malak Memorial	</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2743">88 th World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2744">30 th World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2741">37th Asian JuniorChampionship</a>]

# %%
len(links)
# Out:
# 2585

# %%
print(links)
print(links[::-1])
# Out:
# [<a href="/component/cwyniki/?view=contest&amp;id_zawody=2752">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2753">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2748">48 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2749">27 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2746">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2747">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2745">28 th Waldemar Malak Memorial	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2743">88 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2744">30 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2741">37th Asian JuniorChampionship</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2742">30 th Asian Junior Championship	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2737">Junior European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2738">Junior European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2739">Under 23 European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2740">Under 23 European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2733">Youth European Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2734">Youth European Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2735">Youth European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2736">Youth European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2729">93 rd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2730">30 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2731">55 th Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2732">31 st Polish Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2727">29 th Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2728">29 th Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2721">LZS - Youth Polish Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2722">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2723">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2724">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2714">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2715">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2716">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2717">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2718">Preliminary Junior Polish Championships - OOM	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2719">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2720">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2725">51 st Asian Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2726">31 st Asian Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2711">101 st European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2712">35 th European Championships</a>, <a h ...
# [<a href="/component/cwyniki/?view=contest&amp;id_zawody=24">IX Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=23">X Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=21">XI Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=19">XIV Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=17">XV Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=18">XVI Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2514">27 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2513">28 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2512">29 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2511">30 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=16">XVII Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2510">31 st Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2509">32 nd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1890">33 rd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1891">34 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=15">XVIII Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2538">39 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1904">35 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2543">40 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1909">36 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2542">41 st World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2515">37 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2516">38 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=14">XIX Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2537">42 nd World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2517">39 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2541">43 rd World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2518">40 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2540">44 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=781">2 nd Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2519">41 st Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2539">45 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=782">3 rd  Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2520">42 nd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2536">46 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=327">XIX Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=77">47 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=76">48 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=783">6 th Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=75">49 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=784">7 th Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=74">50 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=12">XXI Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=149 ...

# %%
df['link'] = [str(link) for link in links]
df.head()
# Out:
#         Date                              Name        Place Nation   Gender  \
# 0 2023-12-04                    IWF Grand Prix         Doha    QAT    Males
# 1 2023-12-04                    IWF Grand Prix         Doha    QAT  Females
# 2 2023-11-15  48 th Junior World Championships  Guadalajara    MEX    Males
# 3 2023-11-15  27 th Junior World Championships  Guadalajara    MEX  Females
# 4 2023-10-20  11 th Youth Polish Championships     Biłgoraj    POL    Males
#
#   Age category                                               link
# 0       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 1       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 2       Junior  <a href="/component/cwyniki/?view=contest&amp;...
# 3       Junior  <a href="/component/cwyniki/?view=contest&amp;...
# 4     Youth 15  <a href="/component/cwyniki/?view=contest&amp;...

# %%
df.rename({'Name': 'Competition', 'Place': 'Host City', 'Nation': 'Host Nation', 'Age category': 'Age Category'}, axis=1, inplace=True)
df.head()
# Out:
#         Date                       Competition    Host City Host Nation  \
# 0 2023-12-04                    IWF Grand Prix         Doha         QAT
# 1 2023-12-04                    IWF Grand Prix         Doha         QAT
# 2 2023-11-15  48 th Junior World Championships  Guadalajara         MEX
# 3 2023-11-15  27 th Junior World Championships  Guadalajara         MEX
# 4 2023-10-20  11 th Youth Polish Championships     Biłgoraj         POL
#
#     Gender Age Category                                               link
# 0    Males       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 1  Females       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 2    Males       Junior  <a href="/component/cwyniki/?view=contest&amp;...
# 3  Females       Junior  <a href="/component/cwyniki/?view=contest&amp;...
# 4    Males     Youth 15  <a href="/component/cwyniki/?view=contest&amp;...

# %% [markdown]
# ** Current Project **
# Due to the rule changes in the sport of weighlifting, we are going to focus only on events post the Munich Olympics in 1972. This event ended on September 11, 1972, so we will filter specifically for these events. ALmost all data from this source is from after this time anyway, but it will also likely help prevent some errors when reading in the data.

# %%
# Some masks for faster computation

modern_event_mask = df['Date'] > '1972-09-11'
gender_mask = df['Gender'] == 'Females'
senior_mask = df['Age Category'] == 'Senior'

len(df[modern_event_mask][gender_mask][senior_mask])
# Out:
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_9859/2055256396.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(df[modern_event_mask][gender_mask][senior_mask])
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_9859/2055256396.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   len(df[modern_event_mask][gender_mask][senior_mask])
# 359

# %%
# This is taking my machine about 40 seconds for 10 separate event links

def all_data(guiding_data_frame: pd.DataFrame) -> pd.DataFrame:
    '''Returns a datafram with all results based on the categories contained withing the guiding dataframe'''
    
    # For events with 15 columns
    full_dataframe = pd.DataFrame(columns= ['Date', 'Competition', 'Host City', 'Host Nation', 'Gender', 'Age Category',
                                            'Overall Rank', 'Athlete Name', 'Athlete Nation', 'Bodyweight (kg)', 'Session', 
                                            'Snatch 1', 'Snatch 2', 'Snatch 3', 'Snatch Rank',
                                            'C&J 1', 'C&J 2', 'C&J 3', 'C&J Rank',
                                            'Total (kg)', 'Sinclair'])
    
    # For events with 14 columns (no lettered sessions)
    full_dataframe_short = pd.DataFrame(columns=['Date', 'Competition', 'Host City', 'Host Nation', 'Gender', 'Age Category',
                                            'Overall Rank', 'Athlete Name', 'Athlete Nation', 'Bodyweight (kg)', 
                                            'Snatch 1', 'Snatch 2', 'Snatch 3', 'Snatch Rank',
                                            'C&J 1', 'C&J 2', 'C&J 3', 'C&J Rank',
                                            'Total (kg)', 'Sinclair'])
    
    pattern = re.compile(r'"([^"]*)"')
    for idx, link in enumerate(guiding_data_frame['link']):
        match = pattern.search(link)
        if match:
            event_link = match.group(1)
            absolute_url = 'https://iwrp.net/' + event_link

            response = requests.get(absolute_url)
            if response.status_code == 200:  # Check if request was successful
                soup = BeautifulSoup(response.content, 'html.parser')
                tables = soup.find_all('table')
                for table in tables[:1]: # Currently limiting tables, as I believe all informatin is contained in the first table.
                    with warnings.catch_warnings():
                        warnings.filterwarnings('ignore', category = FutureWarning)
                        try:
                            # This block is executed with 15 columns
                            temp_df = pd.read_html(str(table))[0]
                            # Extract column names from the first row
                            temp_df.columns = temp_df.iloc[0]
                            # Drop the first row (header row)
                            temp_df = temp_df.drop(0)
                            temp_df.columns = ['Overall Rank', 'Athlete Name', 'Athlete Nation', 'Bodyweight (kg)', 'Session', 
                                            'Snatch 1', 'Snatch 2', 'Snatch 3', 'Snatch Rank',
                                            'C&J 1', 'C&J 2', 'C&J 3', 'C&J Rank',
                                            'Total (kg)', 'Sinclair']
                            
                            # Reset index to ensure uniqueness
                            temp_df.reset_index(drop=True, inplace=True)
                            
                            temp_df['Date'] = guiding_data_frame['Date'][idx]
                            temp_df['Competition'] = guiding_data_frame['Competition'][idx]
                            temp_df['Host City'] =  guiding_data_frame['Host City'][idx]
                            temp_df['Host Nation'] = guiding_data_frame['Host Nation'][idx]
                            temp_df['Gender'] = guiding_data_frame['Gender'][idx]
                            temp_df['Age Category'] = guiding_data_frame['Age Category'][idx]
                            
                            # This is to save memory for this expensive process (expensive for my laptop)
                            # temp_df = temp_df.drop_duplicates()
                            
                            # Concatenate the data frames
                            full_dataframe = pd.concat([full_dataframe, temp_df], ignore_index=True)
                            
                        except ValueError:
                            # This block is executed with 14 columns
                            temp_df = pd.read_html(str(table))[0]
                            # Extract column names from the first row
                            temp_df.columns = temp_df.iloc[0]
                            # Drop the first row (header row)
                            temp_df = temp_df.drop(0)
                            if len(temp_df.columns) == 14:
                                temp_df.columns = ['Overall Rank', 'Athlete Name', 'Athlete Nation', 'Bodyweight (kg)', 
                                            'Snatch 1', 'Snatch 2', 'Snatch 3', 'Snatch Rank',
                                            'C&J 1', 'C&J 2', 'C&J 3', 'C&J Rank',
                                            'Total (kg)', 'Sinclair']
                            
                                # Reset index to ensure uniqueness
                                temp_df.reset_index(drop=True, inplace=True)
                            
                                temp_df['Date'] = guiding_data_frame['Date'][idx]
                                temp_df['Competition'] = guiding_data_frame['Competition'][idx]
                                temp_df['Host City'] =  guiding_data_frame['Host City'][idx]
                                temp_df['Host Nation'] = guiding_data_frame['Host Nation'][idx]
                                temp_df['Gender'] = guiding_data_frame['Gender'][idx]
                                temp_df['Age Category'] = guiding_data_frame['Age Category'][idx]
                            else:
                                print(f"Skipped {guiding_data_frame['Competition'][idx]} due to errant columns")
                                continue
                            
                            # This is to save memory for this expensive process (expensive for my laptop)
                            # temp_df = temp_df.drop_duplicates()
                            
                            # Concatenate the data frames
                            full_dataframe_short = pd.concat([full_dataframe_short, temp_df], ignore_index=True)
                        
                       
                # Implement a progress checker to watch for failing internet connection 
                if idx % 10 == 9:
                    print(f"successfully added information from page {idx+1} of {len(guiding_data_frame)}")
                        
                
            else:
                print(f"Failed to fetch data from {absolute_url}. Status code: {response.status_code}")
        else:
            print(f"No match found for link: {link}")
    
    return pd.concat([full_dataframe, full_dataframe_short], ignore_index = True, sort = False) # Join dataframes, filling in NaN as necessary

# %%
# As a test, this is only Senior Women's events from after Munich 1972 (no women's events before then, mask is unnecessary)
# I believe that only international competitions will have the correct data format to be included here.

senior_women_guiding_df = df[modern_event_mask][gender_mask][senior_mask].reset_index(drop=True)

senior_women_data = all_data(senior_women_guiding_df)
# Out:
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_9859/189853789.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   senior_women_guiding_df = df[modern_event_mask][gender_mask][senior_mask].reset_index(drop=True)
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_9859/189853789.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   senior_women_guiding_df = df[modern_event_mask][gender_mask][senior_mask].reset_index(drop=True)
# successfully added information from page 10 of 359
# successfully added information from page 20 of 359
# successfully added information from page 30 of 359
# successfully added information from page 40 of 359
# successfully added information from page 50 of 359
# successfully added information from page 60 of 359
# successfully added information from page 70 of 359
# successfully added information from page 80 of 359
# successfully added information from page 90 of 359
# Skipped Team Women Polish Cup due to errant columns
# successfully added information from page 100 of 359
# successfully added information from page 110 of 359
# successfully added information from page 120 of 359
# successfully added information from page 130 of 359
# Skipped Polish Women Cup due to errant columns
# successfully added information from page 140 of 359
# successfully added information from page 150 of 359
# successfully added information from page 160 of 359
# successfully added information from page 170 of 359
# successfully added information from page 180 of 359
# successfully added information from page 190 of 359
# successfully added information from page 200 of 359
# successfully added information from page 210 of 359
# successfully added information from page 220 of 359
# successfully added information from page 230 of 359
# successfully added information from page 240 of 359
# successfully added information from page 250 of 359
# successfully added information from page 260 of 359
# successfully added information from page 270 of 359
# successfully added information from page 280 of 359
# successfully added information from page 290 of 359
# successfully added information from page 300 of 359
# successfully added information from page 310 of 359
# successfully added information from page 320 of 359
# successfully added information from page 330 of 359
# successfully added information from page 340 of 359
# successfully added information from page 350 of 359

# %% [markdown]
# Maybe I need to work with these in series individually, then create the dataframe from that. That would solve the problem of misaligned columns, and it would likely be faster.

# %%
senior_women_guiding_df.head()
# Out:
#         Date                   Competition Host City Host Nation   Gender  \
# 0 2023-12-04                IWF Grand Prix      Doha         QAT  Females
# 1 2023-09-04     30 th World Championships    Riyadh         KSA  Females
# 2 2023-06-15    30 th Polish Championships    Gdańsk         POL  Females
# 3 2023-05-05     31 st Asian Championships     Jinju         KOR  Females
# 4 2023-04-15  35 th European Championships   Yerevan         ARM  Females
#
#   Age Category                                               link
# 0       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 1       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 2       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 3       Senior  <a href="/component/cwyniki/?view=contest&amp;...
# 4       Senior  <a href="/component/cwyniki/?view=contest&amp;...

# %%
senior_women_data.shape
# Out:
# (33697, 21)

# %% [markdown]
# It's working!!

# %%
# These are leftovers from the import process

senior_women_data[senior_women_data['Sinclair'] == 'Sincler']
# Out:
#             Date                Competition Host City Host Nation   Gender  \
# 0     2023-12-04             IWF Grand Prix      Doha         QAT  Females
# 4     2023-12-04             IWF Grand Prix      Doha         QAT  Females
# 5     2023-12-04             IWF Grand Prix      Doha         QAT  Females
# 32    2023-12-04             IWF Grand Prix      Doha         QAT  Females
# 33    2023-12-04             IWF Grand Prix      Doha         QAT  Females
# ...          ...                        ...       ...         ...      ...
# 33678 1994-03-04  1 st Polish Championships    Elblag         POL  Females
# 33686 1994-03-04  1 st Polish Championships    Elblag         POL  Females
# 33687 1994-03-04  1 st Polish Championships    Elblag         POL  Females
# 33692 1994-03-04  1 st Polish Championships    Elblag         POL  Females
# 33693 1994-03-04  1 st Polish Championships    Elblag         POL  Females
#
#       Age Category Overall Rank      Athlete Name Athlete Nation  \
# 0           Senior           Pl  Surname and name         Nation
# 4           Senior           Pl  Surname and name         Nation
# 5           Senior           Pl  Surname and name         Nation
# 32          Senior           Pl  Surname and name         Nation
# 33          Senior           Pl  Surname and name         Nation
# ...            ...          ...               ...            ...
# 33678       Senior           Pl  Surname and name           Club
# 33686       Senior           Pl  Surname and name           Club
# 33687       Senior           Pl  Surname and name           Club
# 33692       Senior           Pl  Surname and name           Club
# 33693       Senior           Pl  Surname and name           Club
#
#       Bodyweight (kg)  ... Snatch 1 Snatch 2 Snatch 3 Snatch Rank    C&J 1  \
# 0                 B.W  ...        1        2        3         NaN        1
# 4                 B.W  ...   Snatch   Snatch   Snatch         NaN  Cl&Jerk
# 5                 B.W  ...        1        2        3         NaN        1
# 32                B.W  ...   Snatch   Snatch   Snatch         NaN  Cl&Jerk
# 33                B.W  ...        1        2        3         NaN        1
# ...               ...  ...      ...      ...      ...         ...      ...
# 33678             B.W  ...        1        2        3         NaN        1
# 33686             B.W  ...   Snatch   Snatch   Snatch         NaN  Cl&Jerk
# 33687             B.W  ...        1        2        3         NaN        1
# 33692             B.W  ...   Snatch   Snatch   Snatch         NaN  Cl&Jerk
# 33693             B.W  ...        1        2        3         NaN        1
#
#          C&J 2    C&J 3 C&J Rank Total (kg) Sinclair
# 0            2        3      NaN        NaN  Sincler
# 4      Cl&Jerk  Cl&Jerk      NaN        NaN  Sincler
# 5            2        3      NaN        NaN  Sincler
# 32     Cl&Jerk  Cl&Jerk      NaN        NaN  Sincler
# 33           2        3      NaN        NaN  Sincler
# ...        ...      ...      ...        ...      ...
# 33678        2        3      NaN        NaN  Sincler
# 33686  Cl&Jerk  Cl&Jerk      NaN        NaN  Sincler
# 33687        2        3      NaN        NaN  Sincler
# 33692  Cl&Jerk  Cl&Jerk      NaN        NaN  Sincler
# 33693        2        3      NaN        NaN  Sincler
#
# [4847 rows x 21 columns]

# %%
senior_women_data = senior_women_data[senior_women_data['Sinclair'] != 'Sincler']
senior_women_data.shape
# Out:
# (28850, 21)

# %%
senior_women_data['Session'].unique()
# Out:
# array(['A', '49 kg', 'B', 'C', '55 kg', '59 kg', '64 kg', '71 kg',
#        '76 kg', '81 kg', '87 kg', '+ 87 kg', nan, 'D', 'E', '53 kg',
#        '58 kg', '63 kg', '69 kg', '75 kg', '90 kg', '+ 90 kg', '+ 75 kg',
#        'X', 'c', '50 kg', '54 kg', '70 kg', '83 kg', '+ 83 kg', '48 kg',
#        '52 kg', '56 kg', '60 kg', '67,5 kg', '82,5 kg', '+ 82,5 kg'],
#       dtype=object)

# %%
senior_women_data = senior_women_data.drop_duplicates()
senior_women_data.shape
# Out:
# (28848, 21)

# %%
len(senior_women_data['Date'].unique())
# Out:
# 344

# %%
senior_women_data.head()
# Out:
#         Date     Competition Host City Host Nation   Gender Age Category  \
# 1 2023-12-04  IWF Grand Prix      Doha         QAT  Females       Senior
# 2 2023-12-04  IWF Grand Prix      Doha         QAT  Females       Senior
# 3 2023-12-04  IWF Grand Prix      Doha         QAT  Females       Senior
# 6 2023-12-04  IWF Grand Prix      Doha         QAT  Females       Senior
# 7 2023-12-04  IWF Grand Prix      Doha         QAT  Females       Senior
#
#   Overall Rank     Athlete Name Athlete Nation Bodyweight (kg)  ... Snatch 1  \
# 1            1     Won Hyon Sim            PRK           45.00  ...     77.0
# 2            2  Jean Ramos Rose            PHI           45.00  ...     68.0
# 3        49 kg            49 kg          49 kg           49 kg  ...    49 kg
# 6            1     Jiang Huihua            CHN           49.00  ...     90.0
# 7            2      Ri Song gum            PRK           49.00  ...     90.0
#
#   Snatch 2 Snatch 3 Snatch Rank  C&J 1  C&J 2  C&J 3 C&J Rank Total (kg)  \
# 1     82.0     86.0           1   90.0   95.0   99.0        1      181.0
# 2     70.0     70.0           2   85.0   86.0   87.0        2      155.0
# 3    49 kg    49 kg       49 kg  49 kg  49 kg  49 kg    49 kg      49 kg
# 6     94.0     96.0           2  113.0  118.0  120.0        2      216.0
# 7     93.0     95.0           3  120.0  120.0  124.0        1      213.0
#
#   Sinclair
# 1    303.2
# 2    259.7
# 3    49 kg
# 6    337.7
# 7    333.0
#
# [5 rows x 21 columns]

# %%
# This should remove all instances of the extra html chimeras

senior_women_data = senior_women_data[senior_women_data['Overall Rank'] != senior_women_data['Athlete Name']]
senior_women_data.shape
# Out:
# (26603, 21)

# %%
columns_to_convert = ['Overall Rank', 'Bodyweight (kg)', 'Snatch 1', 'Snatch 2', 'Snatch 3', 'Snatch Rank', 
                      'C&J 1', 'C&J 2', 'C&J 3', 'C&J Rank', 'Total (kg)', 'Sinclair']

senior_women_data_numeric = senior_women_data

senior_women_data_numeric[columns_to_convert] = senior_women_data[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# %%
senior_women_data_numeric.dtypes
# Out:
# Date               datetime64[ns]
# Competition                object
# Host City                  object
# Host Nation                object
# Gender                     object
# Age Category               object
# Overall Rank              float64
# Athlete Name               object
# Athlete Nation             object
# Bodyweight (kg)           float64
# Session                    object
# Snatch 1                  float64
# Snatch 2                  float64
# Snatch 3                  float64
# Snatch Rank               float64
# C&J 1                     float64
# C&J 2                     float64
# C&J 3                     float64
# C&J Rank                  float64
# Total (kg)                float64
# Sinclair                  float64
# dtype: object

# %%
senior_women_data_numeric[senior_women_data_numeric['Sinclair'] == 0]
# Out:
#             Date                Competition  Host City Host Nation   Gender  \
# 26    2023-12-04             IWF Grand Prix       Doha         QAT  Females
# 27    2023-12-04             IWF Grand Prix       Doha         QAT  Females
# 28    2023-12-04             IWF Grand Prix       Doha         QAT  Females
# 29    2023-12-04             IWF Grand Prix       Doha         QAT  Females
# 30    2023-12-04             IWF Grand Prix       Doha         QAT  Females
# ...          ...                        ...        ...         ...      ...
# 33429 1997-10-26  4 th Polish Championships   Wiecbork         POL  Females
# 33492 1997-07-19      British Championships      Abbey         GBR  Females
# 33547 1996-05-31  3 rd Polish Championships  Ciechanow         POL  Females
# 33548 1996-05-31  3 rd Polish Championships  Ciechanow         POL  Females
# 33633 1994-03-04  1 st Polish Championships     Elblag         POL  Females
#
#       Age Category  Overall Rank                Athlete Name Athlete Nation  \
# 26          Senior           NaN               Piron Beatriz            DOM
# 27          Senior           NaN      Hariroh Siti Nafisatul            AFG
# 28          Senior           NaN   Lopez Ferrer Ana Gabriela            MEX
# 29          Senior           NaN  Delacruz Jourdan Elizabeth            USA
# 30          Senior           NaN       Saikhom Mirabai Chanu            IND
# ...            ...           ...                         ...            ...
# 33429       Senior           NaN            Pruszek Karolina    TKKF Belfer
# 33492       Senior           NaN               Hayes Suzanne            NaN
# 33547       Senior           NaN            Gawryluk Izabela     KS AZS-AWF
# 33548       Senior           NaN           Gabrusewicz Aneta            NaN
# 33633       Senior           NaN              Karepin Aldona            NaN
#
#        Bodyweight (kg)  ... Snatch 1  Snatch 2  Snatch 3  Snatch Rank  C&J 1  \
# 26               47.68  ...      NaN       NaN       NaN          NaN    NaN
# 27               48.82  ...     72.0      75.0      77.0         13.0   92.0
# 28               48.97  ...     83.0      83.0      83.0          NaN   95.0
# 29               49.00  ...     86.0      89.0      91.0          NaN    NaN
# 30               49.00  ...      NaN       NaN       NaN          NaN    NaN
# ...                ...  ...      ...       ...       ...          ...    ...
# 33429            63.20  ...     52.5      52.5      52.5          NaN   67.5
# 33492            75.70  ...     52.5       NaN       NaN          2.0    NaN
# 33547            64.10  ...      NaN       NaN       NaN          NaN    NaN
# 33548            65.20  ...      NaN       NaN       NaN          NaN    NaN
# 33633            44.90  ...      NaN       NaN       NaN          NaN    NaN
#
#        C&J 2  C&J 3  C&J Rank  Total (kg)  Sinclair
# 26       NaN    NaN       NaN         NaN       0.0
# 27      95.0   95.0       NaN         NaN       0.0
# 28     100.0  103.0       9.0         NaN       0.0
# 29       NaN    NaN       NaN         NaN       0.0
# 30       NaN    NaN       NaN         NaN       0.0
# ...      ...    ...       ...         ...       ...
# 33429   72.5   72.5       6.0         NaN       0.0
# 33492    NaN    NaN       NaN         NaN       0.0
# 33547    NaN    NaN       NaN         NaN       0.0
# 33548    NaN    NaN       NaN         NaN       0.0
# 33633    NaN    NaN       NaN         NaN       0.0
#
# [3201 rows x 21 columns]

# %% [markdown]
# April 3, 2024: At this point, we would be able to fill in any missing total or sinclair values! Since the parser is now working well, I am going to save this data and repeat the process for senior men. Further cleaning will be done later.

# %% [markdown]
# At this point, these data could be turned into a database. I would prefer to be able to do that with all the data at once, however. I am going to save this dataframe as a .csv, then I will be able to load everything at once. For now, we will focus on only Senior men and women.
#
# **Future Steps**
# 1. Turn all numeric columns from strings to numbers. Will need to look for outliers/obviously wrong values.
#
# 2. Concat dataframes and create database -- Postgres? Mysql? SQLite?

# %%
# Save the current data
# We can change the variable names for future use

path = '/Users/aaronkeeney/Documents/Data_Analytics_Projects/Rxpose/senior_women_data.csv'

senior_women_data_numeric.to_csv(path, index=False)

# %% [markdown]
# Next, we will repeat this process with senior men

# %%
modern_event_mask = df['Date'] > '1972-09-11'
gender_mask = df['Gender'] == 'Males'
senior_mask = df['Age Category'] == 'Senior'

senior_men_guiding_df = df[modern_event_mask][gender_mask][senior_mask].reset_index()
senior_men_guiding_df.shape
# Out:
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_9859/4076420237.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   senior_men_guiding_df = df[modern_event_mask][gender_mask][senior_mask].reset_index()
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_9859/4076420237.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   senior_men_guiding_df = df[modern_event_mask][gender_mask][senior_mask].reset_index()
# (520, 8)

# %%
senior_men_data = all_data(senior_men_guiding_df)
# Out:
# successfully added information from page 10 of 520
# successfully added information from page 20 of 520
# successfully added information from page 30 of 520
# successfully added information from page 40 of 520
# successfully added information from page 50 of 520
# successfully added information from page 60 of 520
# successfully added information from page 70 of 520
# successfully added information from page 80 of 520
# successfully added information from page 90 of 520
# successfully added information from page 100 of 520
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# successfully added information from page 110 of 520
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# successfully added information from page 120 of 520
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# successfully added information from page 130 of 520
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# successfully added information from page 140 of 520
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# successfully added information from page 150 of 520
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# successfully added information from page 160 of 520
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# Skipped Polish Team Championships 2016 due to errant columns
# successfully added information from page 170 of 520
# successfully added information from page 180 of 520
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# successfully added information from page 190 of 520
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# successfully added information from page 200 of 520
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# successfully added information from page 210 of 520
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# successfully added information from page 220 of 520
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# successfully added information from page 230 of 520
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# Skipped Polish Team Championships 2015 due to errant columns
# successfully added information from page 240 of 520
# successfully added information from page 250 of 520
# Skipped Polish Team Championships III-r due to errant columns
# Skipped Polish Team Championships III-r due to errant columns
# successfully added information from page 260 of 520
# Skipped Polish Team Championships II-r due to errant columns
# Skipped Polish Team Championships II-r due to errant columns
# Skipped Polish Team Championships II-r due to errant columns
# Skipped Polish Team Championships II-r due to errant columns
# successfully added information from page 270 of 520
# Skipped Polish Team Championships II-r due to errant columns
# Skipped Polish Team Championships II-r due to errant columns
# Skipped Polish Team Championships II-r due to errant columns
# Skipped Polish Team Championships II-r due to errant columns
# Skipped Polish Team Championships I-r due to errant columns
# Skipped Polish Team Championships I-r due to errant columns
# successfully added information from page 280 of 520
# Skipped Polish Team Championships I-r due to errant columns
# Skipped Polish Team Championships I-r due to errant columns
# Skipped Polish Team Championships I-r due to errant columns
# Skipped Polish Team Championships I-r due to errant columns
# Skipped Polish Team Championships I-r due to errant columns
# Skipped Polish Team Championships I-r due to errant columns
# successfully added information from page 290 of 520
# successfully added information from page 300 of 520
# successfully added information from page 310 of 520
# successfully added information from page 320 of 520
# successfully added information from page 330 of 520
# successfully added information from page 340 of 520
# successfully added information from page 350 of 520
# successfully added information from page 360 of 520
# successfully added information from page 370 of 520
# successfully added information from page 380 of 520
# successfully added information from page 390 of 520
# successfully added information from page 400 of 520
# successfully added information from page 410 of 520
# successfully added information from page 420 of 520
# successfully added information from page 430 of 520
# successfully added information from page 440 of 520
# successfully added information from page 450 of 520
# successfully added information from page 460 of 520
# successfully added information from page 470 of 520
# successfully added information from page 480 of 520
# successfully added information from page 490 of 520
# successfully added information from page 500 of 520
# successfully added information from page 510 of 520
# successfully added information from page 520 of 520

# %% [markdown]
# Obviously, there is something different about the Polish Team Championships, but that is outside of our purview for this study.

# %%
senior_men_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43097 entries, 1 to 52115
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             43097 non-null  datetime64[ns]
#  1   Competition      43097 non-null  object
#  2   Host City        42969 non-null  object
#  3   Host Nation      43097 non-null  object
#  4   Gender           43097 non-null  object
#  5   Age Category     43097 non-null  object
#  6   Overall Rank     37762 non-null  float64
#  7   Athlete Name     43097 non-null  object
#  8   Athlete Nation   30171 non-null  object
#  9   Bodyweight (kg)  43097 non-null  float64
#  10  Session          20777 non-null  object
#  11  Snatch 1         42394 non-null  float64
#  12  Snatch 2         35893 non-null  float64
#  13  Snatch 3         35520 non-null  float64
#  14  Snatch Rank      40007 non-null  float64
#  15  C&J 1            40993 non-null  float64
#  16  C&J 2            34415 non-null  float64
#  17  C&J 3            33028 non-null  float64
#  18  C&J Rank         38440 non-null  float64
#  19  Total (kg)       37841 non-null  float64
#  20  Sinclair         43097 non-null  float64
# dtypes: datetime64[ns](1), float64(12), object(8)
# memory usage: 7.2+ MB

# %% [markdown]
# Next, we apply the same transformations for data cleaning that we used for the women's events.

# %%
# Remove title rows
senior_men_data = senior_men_data[senior_men_data['Sinclair'] != 'Sincler']

# Remove category rows
senior_men_data = senior_men_data[senior_men_data['Overall Rank'] != senior_men_data['Athlete Name']]

# Remove Duplicates
senior_men_data = senior_men_data.drop_duplicates()

senior_men_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43097 entries, 1 to 52115
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             43097 non-null  datetime64[ns]
#  1   Competition      43097 non-null  object
#  2   Host City        42969 non-null  object
#  3   Host Nation      43097 non-null  object
#  4   Gender           43097 non-null  object
#  5   Age Category     43097 non-null  object
#  6   Overall Rank     37762 non-null  float64
#  7   Athlete Name     43097 non-null  object
#  8   Athlete Nation   30171 non-null  object
#  9   Bodyweight (kg)  43097 non-null  float64
#  10  Session          20777 non-null  object
#  11  Snatch 1         42394 non-null  float64
#  12  Snatch 2         35893 non-null  float64
#  13  Snatch 3         35520 non-null  float64
#  14  Snatch Rank      40007 non-null  float64
#  15  C&J 1            40993 non-null  float64
#  16  C&J 2            34415 non-null  float64
#  17  C&J 3            33028 non-null  float64
#  18  C&J Rank         38440 non-null  float64
#  19  Total (kg)       37841 non-null  float64
#  20  Sinclair         43097 non-null  float64
# dtypes: datetime64[ns](1), float64(12), object(8)
# memory usage: 7.2+ MB

# %%
# Duplicate datafram and convert columns to numeric

senior_men_data_numeric = senior_men_data.reset_index()

senior_men_data_numeric[columns_to_convert] = senior_men_data_numeric[columns_to_convert].apply(pd.to_numeric, errors='coerce')

senior_men_data_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43097 entries, 0 to 43096
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            43097 non-null  int64
#  1   Date             43097 non-null  datetime64[ns]
#  2   Competition      43097 non-null  object
#  3   Host City        42969 non-null  object
#  4   Host Nation      43097 non-null  object
#  5   Gender           43097 non-null  object
#  6   Age Category     43097 non-null  object
#  7   Overall Rank     37762 non-null  float64
#  8   Athlete Name     43097 non-null  object
#  9   Athlete Nation   30171 non-null  object
#  10  Bodyweight (kg)  43097 non-null  float64
#  11  Session          20777 non-null  object
#  12  Snatch 1         42394 non-null  float64
#  13  Snatch 2         35893 non-null  float64
#  14  Snatch 3         35520 non-null  float64
#  15  Snatch Rank      40007 non-null  float64
#  16  C&J 1            40993 non-null  float64
#  17  C&J 2            34415 non-null  float64
#  18  C&J 3            33028 non-null  float64
#  19  C&J Rank         38440 non-null  float64
#  20  Total (kg)       37841 non-null  float64
#  21  Sinclair         43097 non-null  float64
# dtypes: datetime64[ns](1), float64(12), int64(1), object(8)
# memory usage: 7.2+ MB

# %%
senior_men_data_numeric.sort_values(by='Sinclair', ascending=False)
# Out:
#        index       Date                    Competition Host City Host Nation  \
# 25909  30454 2017-11-03           German Championships    Speyer         GER
# 1454    1680 2022-05-28  100 th European Championships    Tirana         ALB
# 1455    1681 2022-05-28  100 th European Championships    Tirana         ALB
# 1456    1682 2022-05-28  100 th European Championships    Tirana         ALB
# 1677    1931 2021-12-07      86 th World Championships  Tashkent         UZB
# ...      ...        ...                            ...       ...         ...
# 21372  24988 1979-11-08      53 rd World Championships  Saloniki         GRE
# 21373  24989 1979-11-08      53 rd World Championships  Saloniki         GRE
# 21374  24990 1979-11-08      53 rd World Championships  Saloniki         GRE
# 21375  24991 1979-11-08      53 rd World Championships  Saloniki         GRE
# 43096  52115 1977-05-20     47 th Polish Championships   Gliwice         POL
#
#       Gender Age Category  Overall Rank            Athlete Name  \
# 25909  Males       Senior           6.0  Schiffer Karl Waldemar
# 1454   Males       Senior           1.0        Talakhadze Lasha
# 1455   Males       Senior           2.0        Varazdat Lalayan
# 1456   Males       Senior           3.0            Minasyan Gor
# 1677   Males       Senior           1.0        Talakhadze Lasha
# ...      ...          ...           ...                     ...
# 21372  Males       Senior           8.0    Chavigny Jean-Claude
# 21373  Males       Senior           9.0           Saito Takashi
# 21374  Males       Senior          10.0             Tan Hanyong
# 21375  Males       Senior          11.0  Loscos Rodrigues Julio
# 43096  Males       Senior           NaN         Palka Eugeniusz
#
#       Athlete Nation  ...  Snatch 1 Snatch 2  Snatch 3  Snatch Rank  C&J 1  \
# 25909            NaN  ...     115.0    120.0     125.0          6.0  140.0
# 1454             GEO  ...     208.0    212.0     217.0          1.0  245.0
# 1455             ARM  ...     203.0    211.0     211.0          2.0  240.0
# 1456             ARM  ...     202.0    210.0     210.0          3.0  236.0
# 1677             GEO  ...     210.0    218.0     225.0          1.0  247.0
# ...              ...  ...       ...      ...       ...          ...    ...
# 21372            FRA  ...     115.0      NaN       NaN         10.0  147.5
# 21373            JPN  ...     115.0      NaN       NaN         11.0  147.5
# 21374            CHN  ...     115.0      NaN       NaN         12.0  147.5
# 21375            CUB  ...     117.5      NaN       NaN          9.0  145.0
# 43096            NaN  ...       NaN      NaN       NaN          NaN    NaN
#
#        C&J 2  C&J 3  C&J Rank  Total (kg)  Sinclair
# 25909  146.0  151.0       6.0       271.0  111132.0
# 1454   253.0    NaN       1.0       462.0     510.8
# 1455   252.0  252.0       2.0       451.0     498.6
# 1456   245.0  245.0       4.0       446.0     493.1
# 1677   257.0  267.0       1.0       492.0     492.5
# ...      ...    ...       ...         ...       ...
# 21372    NaN    NaN       5.0       262.5       0.0
# 21373    NaN    NaN       6.0       262.5       0.0
# 21374    NaN    NaN       9.0       262.5       0.0
# 21375    NaN    NaN      13.0       262.5       0.0
# 43096    NaN    NaN       NaN         NaN       0.0
#
# [43097 rows x 22 columns]

# %% [markdown]
# There appear to be a few errors, as there is one Sinclair that is nonsensical, and the other values should be checked. As far as I know, Lasha has not been credited with a Sinclair over 500...

# %%
# Save men's data in case it gets messed up

path = '/Users/aaronkeeney/Documents/Data_Analytics_Projects/Rxpose/senior_men_data.csv'

senior_men_data_numeric.to_csv(path, index=False)

# %%
# In case of crashes (or just future data analysis), use this cell to reload data from source

senior_women_data_loaded = pd.read_csv('/Users/aaronkeeney/Documents/Data_Analytics_Projects/Rxpose/senior_women_data.csv')

senior_men_data_loaded = pd.read_csv( '/Users/aaronkeeney/Documents/Data_Analytics_Projects/Rxpose/senior_men_data.csv')
# Out:
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_19836/533296077.py:5: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   senior_men_data_loaded = pd.read_csv( '/Users/aaronkeeney/Documents/Data_Analytics_Projects/Rxpose/senior_men_data.csv')

# %%
# Combining all these data into one data frame

# In the future, these extra columns should disappear, as I added 'index=False' to the to_csv() function

all_senior_data_loaded = pd.concat([senior_men_data_loaded, senior_women_data_loaded], axis=0)

all_senior_data_loaded = all_senior_data_loaded.drop(all_senior_data_loaded.columns[[0,1]], axis=1)

all_senior_data_loaded.head()
# Out:
#          Date     Competition Host City Host Nation Gender Age Category  \
# 0  2023-12-04  IWF Grand Prix      Doha         QAT  Males       Senior
# 1  2023-12-04  IWF Grand Prix      Doha         QAT  Males       Senior
# 2  2023-12-04  IWF Grand Prix      Doha         QAT  Males       Senior
# 3  2023-12-04  IWF Grand Prix      Doha         QAT  Males       Senior
# 4  2023-12-04  IWF Grand Prix      Doha         QAT  Males       Senior
#
#    Overall Rank                 Athlete Name Athlete Nation  Bodyweight (kg)  \
# 0           1.0                 Pang Un Chol            PRK            54.94
# 1           2.0           Nugroho Satrio Adi            INA            54.79
# 2           3.0  Yodage Dilanka Isuru Kumara            SRI            55.00
# 3           4.0         Rizqih Muhammad Ibnu            INA            55.00
# 4           5.0        Taj Md Ashikur Rahman            BAN            55.00
#
#    ... Snatch 1  Snatch 2  Snatch 3  Snatch Rank  C&J 1  C&J 2  C&J 3  \
# 0  ...    110.0     114.0     116.0          1.0  142.0  148.0  152.0
# 1  ...    108.0     112.0     115.0          2.0  135.0  139.0  144.0
# 2  ...    106.0     112.0     114.0          4.0  133.0  139.0  140.0
# 3  ...    111.0     111.0     113.0          3.0  130.0  134.0  134.0
# 4  ...     93.0      97.0     100.0          6.0  112.0  118.0  118.0
#
#    C&J Rank  Total (kg)  Sinclair
# 0       1.0       268.0     441.0
# 1       2.0       254.0     418.9
# 2       3.0       245.0     402.8
# 3       4.0       243.0     399.5
# 4       5.0       212.0     348.5
#
# [5 rows x 21 columns]

# %%
all_senior_data_loaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69700 entries, 0 to 26602
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             69700 non-null  object
#  1   Competition      69700 non-null  object
#  2   Host City        69472 non-null  object
#  3   Host Nation      69700 non-null  object
#  4   Gender           69700 non-null  object
#  5   Age Category     69700 non-null  object
#  6   Overall Rank     62303 non-null  float64
#  7   Athlete Name     69700 non-null  object
#  8   Athlete Nation   48424 non-null  object
#  9   Bodyweight (kg)  69700 non-null  float64
#  10  Session          33815 non-null  object
#  11  Snatch 1         68826 non-null  float64
#  12  Snatch 2         60058 non-null  float64
#  13  Snatch 3         59548 non-null  float64
#  14  Snatch Rank      65138 non-null  float64
#  15  C&J 1            67033 non-null  float64
#  16  C&J 2            58074 non-null  float64
#  17  C&J 3            56112 non-null  float64
#  18  C&J Rank         63168 non-null  float64
#  19  Total (kg)       62423 non-null  float64
#  20  Sinclair         69700 non-null  float64
# dtypes: float64(12), object(9)
# memory usage: 11.7+ MB

# %% [markdown]
# For some reason, the Date column is no longer a datetime object after reloading the data. Easy fix, though.

# %%
all_senior_data_loaded['Date'] = pd.to_datetime(all_senior_data_loaded['Date'])
all_senior_data_loaded = all_senior_data_loaded.reset_index(drop=True)
all_senior_data_loaded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69700 entries, 0 to 69699
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             69700 non-null  datetime64[ns]
#  1   Competition      69700 non-null  object
#  2   Host City        69472 non-null  object
#  3   Host Nation      69700 non-null  object
#  4   Gender           69700 non-null  object
#  5   Age Category     69700 non-null  object
#  6   Overall Rank     62303 non-null  float64
#  7   Athlete Name     69700 non-null  object
#  8   Athlete Nation   48424 non-null  object
#  9   Bodyweight (kg)  69700 non-null  float64
#  10  Session          33815 non-null  object
#  11  Snatch 1         68826 non-null  float64
#  12  Snatch 2         60058 non-null  float64
#  13  Snatch 3         59548 non-null  float64
#  14  Snatch Rank      65138 non-null  float64
#  15  C&J 1            67033 non-null  float64
#  16  C&J 2            58074 non-null  float64
#  17  C&J 3            56112 non-null  float64
#  18  C&J Rank         63168 non-null  float64
#  19  Total (kg)       62423 non-null  float64
#  20  Sinclair         69700 non-null  float64
# dtypes: datetime64[ns](1), float64(12), object(8)
# memory usage: 11.2+ MB

# %% [markdown]
# ~~At this point, we could upload the senior data to the database. Below, I am going to filter these data and preserve only the pieces necessary for the current analysis project.~~
#
# April 4, 2023: I am going to continue to clean the data first and create a usable database. We can return to the actual analysis later, but cleaning all data first will reduce the amount of work in the long term.

# %%
all_senior_data_loaded.sort_values(by = 'Sinclair', ascending = False)
# Out:
#             Date                        Competition      Host City  \
# 25909 2017-11-03               German Championships         Speyer
# 49505 2014-05-26  24 th Pan Americana Championships  Santo Domingo
# 59576 2017-11-03               German Championships         Speyer
# 59577 2017-11-03               German Championships         Speyer
# 1454  2022-05-28      100 th European Championships         Tirana
# ...          ...                                ...            ...
# 770   2023-04-15      101 st European Championships        Yerevan
# 11540 2007-09-17          76 th World Championships     Chiang Mai
# 11541 2007-09-17          76 th World Championships     Chiang Mai
# 11542 2007-09-17          76 th World Championships     Chiang Mai
# 62327 2016-02-21               Italian Championship          Ostia
#
#       Host Nation   Gender Age Category  Overall Rank  \
# 25909         GER    Males       Senior           6.0
# 49505         DOM  Females       Senior           7.0
# 59576         GER  Females       Senior           3.0
# 59577         GER  Females       Senior           4.0
# 1454          ALB    Males       Senior           1.0
# ...           ...      ...          ...           ...
# 770           ARM    Males       Senior           NaN
# 11540         THA    Males       Senior           NaN
# 11541         THA    Males       Senior           NaN
# 11542         THA    Males       Senior           NaN
# 62327         ITA  Females       Senior           4.0
#
#                        Athlete Name Athlete Nation  Bodyweight (kg)  ...  \
# 25909        Schiffer Karl Waldemar            NaN             2.40  ...
# 49505  Lima De Araujo Monique Maria            BRA             4.70  ...
# 59576           Winterholler Nicole            NaN             3.50  ...
# 59577                  Jacobs Sarah            NaN             3.60  ...
# 1454               Talakhadze Lasha            GEO           110.00  ...
# ...                             ...            ...              ...  ...
# 770              Imadouchene Romain            FRA            92.52  ...
# 11540                        Qiu Le            CHN            61.39  ...
# 11541                Alpanov Ruslan            UZB            61.58  ...
# 11542            Vidanage Chinthana            SRI            61.75  ...
# 62327                 Locati Ilaria            NaN            52.79  ...
#
#       Snatch 1  Snatch 2  Snatch 3  Snatch Rank  C&J 1  C&J 2  C&J 3  \
# 25909    115.0     120.0     125.0          6.0  140.0  146.0  151.0
# 49505    100.0     105.0     105.0          4.0  121.0  124.0  126.0
# 59576     65.0      69.0      73.0          3.0   85.0   89.0   92.0
# 59577     68.0      68.0      73.0          4.0   85.0   89.0   92.0
# 1454     208.0     212.0     217.0          1.0  245.0  253.0    NaN
# ...        ...       ...       ...          ...    ...    ...    ...
# 770      160.0     160.0     160.0          NaN    NaN    NaN    NaN
# 11540    137.0     141.0     141.0          4.0    NaN    NaN    NaN
# 11541    120.0     125.0     125.0         28.0  145.0  145.0  145.0
# 11542    121.0     125.0     125.0         24.0  160.0  160.0  160.0
# 62327     53.0      57.0      57.0          4.0   62.0   65.0   71.0
#
#        C&J Rank  Total (kg)  Sinclair
# 25909       6.0       271.0  111132.0
# 49505       8.0       221.0   22829.4
# 59576       3.0       162.0   21046.7
# 59577       4.0       157.0   18975.7
# 1454        1.0       462.0     510.8
# ...         ...         ...       ...
# 770         NaN         NaN       0.0
# 11540       NaN         NaN       0.0
# 11541       NaN         NaN       0.0
# 11542       NaN         NaN       0.0
# 62327       4.0       122.0       0.0
#
# [69700 rows x 21 columns]

# %%
all_senior_data_loaded[all_senior_data_loaded['Athlete Name'] == 'Talakhadze Lasha'].sort_values(by='Sinclair', ascending=False)
# Out:
#             Date                    Competition       Host City Host Nation  \
# 1454  2022-05-28  100 th European Championships          Tirana         ALB
# 1677  2021-12-07      86 th World Championships        Tashkent         UZB
# 1883  2021-07-23           XXXII Olympics Games           Tokyo         JPN
# 2228  2021-04-03   99 th European Championships          Moscow         RUS
# 2871  2019-09-18      85 th World Championships         Pattaya         THA
# 3424  2019-04-06   98 th European Championships          Batumi         GEO
# 4450  2017-11-29      83 rd World Championships         Anaheim         USA
# 806   2023-04-15  101 st European Championships         Yerevan         ARM
# 5359  2016-08-10            XXXI Olympics Games  Rio de Janeiro         BRA
# 3774  2018-11-01      84 th World Championships        Ashgabat         TKM
# 511   2023-09-04      88 th World Championships          Riyadh         KSA
# 2420  2020-01-27                      World Cup            Roma         ROM
# 1058  2022-12-05      87 th World Championships          Bogota         COL
# 5060  2017-04-02   96 th European Championships           Split         CRO
# 5980  2016-04-17   95 th European Championships           Forde         NOR
# 4278  2018-03-26   97 th European Championships       Bucharest         ROU
# 6358  2015-11-20      82 nd World Championships         Houston         USA
# 1186  2022-09-03  27 th Waldemar Malak Memorial          Gdansk         POL
# 9792  2011-11-05      79 th World Championships           Paris         FRA
# 10423 2010-09-22      78 th World Championships         Antalya         TUR
#
#       Gender Age Category  Overall Rank      Athlete Name Athlete Nation  \
# 1454   Males       Senior           1.0  Talakhadze Lasha            GEO
# 1677   Males       Senior           1.0  Talakhadze Lasha            GEO
# 1883   Males       Senior           1.0  Talakhadze Lasha            GEO
# 2228   Males       Senior           1.0  Talakhadze Lasha            GEO
# 2871   Males       Senior           1.0  Talakhadze Lasha            GEO
# 3424   Males       Senior           1.0  Talakhadze Lasha            GEO
# 4450   Males       Senior           1.0  Talakhadze Lasha            GEO
# 806    Males       Senior           1.0  Talakhadze Lasha            GEO
# 5359   Males       Senior           1.0  Talakhadze Lasha            GEO
# 3774   Males       Senior           1.0  Talakhadze Lasha            GEO
# 511    Males       Senior           1.0  Talakhadze Lasha            GEO
# 2420   Males       Senior           1.0  Talakhadze Lasha            GEO
# 1058   Males       Senior           1.0  Talakhadze Lasha            GEO
# 5060   Males       Senior           1.0  Talakhadze Lasha            GEO
# 5980   Males       Senior           1.0  Talakhadze Lasha            GEO
# 4278   Males       Senior           1.0  Talakhadze Lasha            GEO
# 6358   Males       Senior           1.0  Talakhadze Lasha            GEO
# 1186   Males       Senior           1.0  Talakhadze Lasha            GEO
# 9792   Males       Senior          20.0  Talakhadze Lasha            GEO
# 10423  Males       Senior           NaN  Talakhadze Lasha            GEO
#
#        Bodyweight (kg)  ... Snatch 1  Snatch 2  Snatch 3  Snatch Rank  C&J 1  \
# 1454            110.00  ...    208.0     212.0     217.0          1.0  245.0
# 1677            182.90  ...    210.0     218.0     225.0          1.0  247.0
# 1883            177.00  ...    208.0     215.0     223.0          1.0  245.0
# 2228            176.30  ...    211.0     217.0     222.0          1.0  245.0
# 2871            168.65  ...    208.0     215.0     220.0          1.0  247.0
# 3424            170.10  ...    208.0     218.0       NaN          1.0  245.0
# 4450            166.00  ...    210.0     215.0     220.0          1.0  243.0
# 806             175.78  ...    210.0     217.0     222.0          1.0  246.0
# 5359            157.34  ...    205.0     210.0     215.0          2.0  242.0
# 3774            169.31  ...    207.0     212.0     217.0          1.0  245.0
# 511             177.37  ...    208.0     215.0     220.0          1.0  245.0
# 2420            171.00  ...    200.0     210.0     215.0          1.0  235.0
# 1058            166.50  ...    208.0     215.0     220.0          2.0  245.0
# 5060            158.10  ...    203.0     210.0     217.0          1.0  238.0
# 5980            156.76  ...    200.0     207.0     212.0          1.0  235.0
# 4278            165.56  ...    200.0     210.0     221.0          1.0  235.0
# 6358            155.12  ...    200.0     200.0     207.0          1.0  238.0
# 1186            172.90  ...    190.0     200.0     205.0          1.0  225.0
# 9792            143.11  ...    175.0     180.0     187.0         16.0  207.0
# 10423           130.34  ...    157.0     162.0     162.0         27.0  180.0
#
#        C&J 2  C&J 3  C&J Rank  Total (kg)  Sinclair
# 1454   253.0    NaN       1.0       462.0     510.8
# 1677   257.0  267.0       1.0       492.0     492.5
# 1883   255.0  265.0       1.0       488.0     489.2
# 2228   253.0  263.0       1.0       485.0     486.3
# 2871   255.0  264.0       1.0       484.0     484.2
# 3424   260.0    NaN       1.0       478.0     478.1
# 4450   250.0  257.0       1.0       477.0     477.5
# 806    252.0    NaN       1.0       474.0     475.4
# 5359   247.0  258.0       1.0       473.0     474.7
# 3774   252.0  257.0       1.0       474.0     474.2
# 511    253.0  260.0       1.0       473.0     474.1
# 2420   245.0  255.0       1.0       470.0     470.1
# 1058   245.0  251.0       1.0       466.0     469.3
# 5060   245.0  250.0       1.0       467.0     468.7
# 5980   241.0  251.0       1.0       463.0     464.8
# 4278   247.0    NaN       1.0       457.0     457.5
# 6358   247.0  247.0       2.0       454.0     456.1
# 1186   235.0    NaN       1.0       440.0     441.8
# 9792   207.0    NaN      25.0       387.0     392.1
# 10423  180.0    NaN       NaN         NaN       0.0
#
# [20 rows x 21 columns]

# %% [markdown]
# From this small cross section, we can see that there are a few errors present. The sinclair over 500 is too high, but it is likely due to crediting Lasha with a bodyweight of 110kg. He was certainly larger than that for this competition. ~~We can also see some missing values for the total when there are valid numbers in both the snatch and clean and jerk. This should be filled in, and there are likely other places in this data set where this is the case.~~
#
# Turns out the numbers in the Snatch and C&J columns are attempts, not makes. Thus, we will trust the 'Total (kg)' values as being corrct

# %%
# THIS FUNCTION IS NO LONGER USEFUL (APRIL 4, 2025)

# Fill in totals that have valid snatches and clean and jerks

def update_totals(row):
    if pd.isnull(row['Total (kg)']):
        snatch_max = max(row[['Snatch 1', 'Snatch 2', 'Snatch 3']])
        cj_max = max(row[['C&J 1', 'C&J 2', 'C&J 3']])
        if not np.isnan(snatch_max) and not np.isnan(cj_max):
            return snatch_max + cj_max
    return row['Total (kg)']

#all_senior_data_loaded['Total (kg)'] = all_senior_data_loaded.apply(update_totals, axis=1)

# %% [markdown]
# ### Sinclair Experiment ###
#
# Below, we are going to do a calculated Sinclair to try find a little more consistency. We are going to use the total and the credited bodyweight from the table to do this calculation. The Sinclair coefficients change every Olympic cycle. However, the changes are small, and if we scale everyone relative to the same numbers, I believe this will be a simple and equitable way to proceed. From the previous version (done within SQLite)
#
# WHEN (sex = 'F')
#
#     THEN  total_kg* POWER(10, 0.787004341*POWER(LOG10(weight_class_kg/153.757),2))
#
#     ELSE  total_kg* POWER(10, 0.722762521*POWER(LOG10(weight_class_kg/193.609),2))
#
# In this python verion, we will be using the total kilograms, and the listed bodyweight for each athlete. For a detailed explanation of Sinclair values, see this [link](https://vektlofting.no/siteassets/dokumenter/aktiv-idrett/stevneprotokoller/sinclair-koeffisienter-2021-2024/2021-sinclair_coefficients.pdf).

# %%
def calculate_sinclair(row):
    if not row['Bodyweight (kg)']:
        return row['Total (kg)']
    if row['Gender'] == 'Females' and row['Bodyweight (kg)'] < 153.757:
        return row['Total (kg)']  * 10**(0.78700434110 * (np.log10(row['Bodyweight (kg)'] / 153.757)) ** 2)
    if row['Gender'] == 'Males' and row['Bodyweight (kg)'] < 193.609:
        return row['Total (kg)']  * 10**(0.722762521 * (np.log10(row['Bodyweight (kg)'] / 193.609)) ** 2)
    else:
        return row['Total (kg)']

# %%
all_senior_data_loaded['Sinclair (calculated)'] = all_senior_data_loaded.apply(calculate_sinclair, axis=1)

# %%
all_senior_data_loaded.sort_values(by='Sinclair (calculated)', ascending=False)[:20]
# Out:
#             Date                        Competition      Host City  \
# 25909 2017-11-03               German Championships         Speyer
# 59576 2017-11-03               German Championships         Speyer
# 59577 2017-11-03               German Championships         Speyer
# 49505 2014-05-26  24 th Pan Americana Championships  Santo Domingo
# 19283 1988-09-18                XXIV Olympics Games          Seoul
# 19664 1986-11-08          60 th World Championships          Sofia
# 1454  2022-05-28      100 th European Championships         Tirana
# 19728 1986-11-08          60 th World Championships          Sofia
# 21248 1980-07-20          54 th World Championships         Moskau
# 21075 1980-07-20                XXII Olympics Games         Moskau
# 20679 1982-09-18          56 th World Championships      Ljubljana
# 19427 1988-09-18                XXIV Olympics Games          Seoul
# 20500 1983-10-22          57 th World Championships         Moskau
# 19565 1987-09-07          61 st World Championships        Ostrava
# 6849  2014-11-04          81 st World Championships         Almaty
# 19773 1986-11-08          60 th World Championships          Sofia
# 14576 2000-09-15               XXVII Olympics Games         Sydney
# 14998 1999-11-22          70 th World Championships          Athen
# 7972  2013-10-20          80 th World Championships        Wroclaw
# 19702 1986-11-08          60 th World Championships          Sofia
#
#       Host Nation   Gender Age Category  Overall Rank  \
# 25909         GER    Males       Senior           6.0
# 59576         GER  Females       Senior           3.0
# 59577         GER  Females       Senior           4.0
# 49505         DOM  Females       Senior           7.0
# 19283         KOR    Males       Senior           1.0
# 19664         BUL    Males       Senior           1.0
# 1454          ALB    Males       Senior           1.0
# 19728         BUL    Males       Senior           1.0
# 21248         URS    Males       Senior           1.0
# 21075         URS    Males       Senior           1.0
# 20679         YUG    Males       Senior           1.0
# 19427         KOR    Males       Senior           1.0
# 20500         URS    Males       Senior           1.0
# 19565         TCH    Males       Senior           1.0
# 6849          KAZ    Males       Senior           1.0
# 19773         BUL    Males       Senior           1.0
# 14576         AUS    Males       Senior           1.0
# 14998         GRE    Males       Senior           1.0
# 7972          POL    Males       Senior           1.0
# 19702         BUL    Males       Senior           1.0
#
#                        Athlete Name Athlete Nation  Bodyweight (kg)  ...  \
# 25909        Schiffer Karl Waldemar            NaN             2.40  ...
# 59576           Winterholler Nicole            NaN             3.50  ...
# 59577                  Jacobs Sarah            NaN             3.60  ...
# 49505  Lima De Araujo Monique Maria            BRA             4.70  ...
# 19283             Suleymanoglu Naim            TUR            59.70  ...
# 19664             Suleymanoglu Naim            TUR            59.80  ...
# 1454               Talakhadze Lasha            GEO           110.00  ...
# 19728                   Zlatev Asen            BUL            82.30  ...
# 21248               Vardanyan Yurik            URS            81.70  ...
# 21075               Vardanyan Yurik            URS            81.70  ...
# 20679                   Zlatev Asen            BUL            81.80  ...
# 19427              Zakharevich Yuri            URS           109.55  ...
# 20500                Blagoev Blagoi            BUL            89.55  ...
# 19565              Khrapaty Anatoli            URS            89.60  ...
# 6849                       Liao Hui            CHN            68.68  ...
# 19773                     Vlad Nicu            ROM            99.60  ...
# 14576               Boevski Galabin            BUL            68.78  ...
# 14998               Boevski Galabin            BUL            68.65  ...
# 7972                       Liao Hui            CHN            68.52  ...
# 19702            Varbanov Alexander            BUL            74.65  ...
#
#       Snatch 2  Snatch 3  Snatch Rank  C&J 1  C&J 2  C&J 3  C&J Rank  \
# 25909    120.0     125.0          6.0  140.0  146.0  151.0       6.0
# 59576     69.0      73.0          3.0   85.0   89.0   92.0       3.0
# 59577     68.0      73.0          4.0   85.0   89.0   92.0       4.0
# 49505    105.0     105.0          4.0  121.0  124.0  126.0       8.0
# 19283    150.5     152.5          1.0  175.0  188.5  190.0       1.0
# 19664      NaN       NaN          1.0  187.5    NaN    NaN       1.0
# 1454     212.0     217.0          1.0  245.0  253.0    NaN       1.0
# 19728      NaN       NaN          1.0  225.0    NaN    NaN       1.0
# 21248    172.5     177.5          1.0  205.0  215.5  222.5       1.0
# 21075    172.5     177.5          1.0  205.0  215.5  222.5       1.0
# 20679      NaN       NaN          1.0  220.0    NaN    NaN       1.0
# 19427    205.0     210.0          1.0  245.0  251.0  251.0       1.0
# 20500      NaN       NaN          1.0  227.5    NaN    NaN       1.0
# 19565      NaN       NaN          2.0  232.5    NaN    NaN       1.0
# 6849     160.0     166.0          1.0  185.0  193.0    NaN       1.0
# 19773      NaN       NaN          1.0  237.5    NaN    NaN       1.0
# 14576    160.0     162.5          2.0  185.0  190.0  196.5       1.0
# 14998    160.5     162.5          1.0  185.0  190.0  196.0       1.0
# 7972     160.0     166.0          1.0  186.0  195.0  198.0       1.0
# 19702      NaN       NaN          2.0  212.5    NaN    NaN       1.0
#
#        Total (kg)  Sinclair  Sinclair (calculated)
# 25909       271.0  111132.0          114978.167885
# 59576       162.0   21046.7           21547.167949
# 59577       157.0   18975.7           19420.376385
# 49505       221.0   22829.4           14129.191246
# 19283       342.5       0.0             528.874967
# 19664       335.0       0.0             516.655165
# 1454        462.0     510.8             510.757455
# 19728       405.0       0.0             509.587669
# 21248       400.0       0.0             505.286624
# 21075       400.0       0.0             505.286624
# 20679       400.0       0.0             504.952189
# 19427       455.0       0.0             503.753757
# 20500       417.5       0.0             503.153733
# 19565       417.5       0.0             503.017853
# 6849        359.0     484.4             502.939595
# 19773       437.5       0.0             502.579235
# 14576       359.0     469.6             502.464053
# 14998       358.5     469.6             502.381939
# 7972        358.0     483.8             502.301165
# 19702       377.5       0.0             502.034044
#
# [20 rows x 22 columns]

# %% [markdown]
# This has done a pretty decent job, at least from looking at the top performances. We should remove all the absurdly large sinclair values (those over 550 kg), and we need to update Lasha Talakhadze's bodyweight where he is listed as weighing 110 kg. Even though he is the strongest weighlifter in history, this value will mess up future calculations.

# %%
def fix_bodyweights(row):
    # Fix 
    if row['Bodyweight (kg)'] < 10:
        return 0
    if row['Bodyweight (kg)'] == 110 and row['Athlete Name'] == 'Talakhadze Lasha':
        return 183 # Lasha's weight from Wikipedia as of April 4, 2024
    else:
        return row['Bodyweight (kg)']

# %%
all_senior_data_loaded['Bodyweight (kg)'] = all_senior_data_loaded.apply(fix_bodyweights, axis=1)
all_senior_data_loaded['Sinclair (calculated)'] = all_senior_data_loaded.apply(calculate_sinclair, axis=1)

# %%
all_senior_data_loaded.sort_values(by='Sinclair (calculated)', ascending=False)[:20]
# Out:
#             Date                    Competition       Host City Host Nation  \
# 19283 1988-09-18            XXIV Olympics Games           Seoul         KOR
# 19664 1986-11-08      60 th World Championships           Sofia         BUL
# 19728 1986-11-08      60 th World Championships           Sofia         BUL
# 21075 1980-07-20            XXII Olympics Games          Moskau         URS
# 21248 1980-07-20      54 th World Championships          Moskau         URS
# 20679 1982-09-18      56 th World Championships       Ljubljana         YUG
# 19427 1988-09-18            XXIV Olympics Games           Seoul         KOR
# 20500 1983-10-22      57 th World Championships          Moskau         URS
# 19565 1987-09-07      61 st World Championships         Ostrava         TCH
# 6849  2014-11-04      81 st World Championships          Almaty         KAZ
# 19773 1986-11-08      60 th World Championships           Sofia         BUL
# 14576 2000-09-15           XXVII Olympics Games          Sydney         AUS
# 14998 1999-11-22      70 th World Championships           Athen         GRE
# 7972  2013-10-20      80 th World Championships         Wroclaw         POL
# 19702 1986-11-08      60 th World Championships           Sofia         BUL
# 19918 1985-02-01      59 th World Championships      Sodertalje         SWE
# 26221 2017-08-28  13 th National Games of China    Tianjin - 天津         CHN
# 6100  2015-11-20      82 nd World Championships         Houston         USA
# 19155 1989-09-16      62 nd World Championships           Athen         GRE
# 5230  2016-08-10            XXXI Olympics Games  Rio de Janeiro         BRA
#
#       Gender Age Category  Overall Rank        Athlete Name Athlete Nation  \
# 19283  Males       Senior           1.0   Suleymanoglu Naim            TUR
# 19664  Males       Senior           1.0   Suleymanoglu Naim            TUR
# 19728  Males       Senior           1.0         Zlatev Asen            BUL
# 21075  Males       Senior           1.0     Vardanyan Yurik            URS
# 21248  Males       Senior           1.0     Vardanyan Yurik            URS
# 20679  Males       Senior           1.0         Zlatev Asen            BUL
# 19427  Males       Senior           1.0    Zakharevich Yuri            URS
# 20500  Males       Senior           1.0      Blagoev Blagoi            BUL
# 19565  Males       Senior           1.0    Khrapaty Anatoli            URS
# 6849   Males       Senior           1.0            Liao Hui            CHN
# 19773  Males       Senior           1.0           Vlad Nicu            ROM
# 14576  Males       Senior           1.0     Boevski Galabin            BUL
# 14998  Males       Senior           1.0     Boevski Galabin            BUL
# 7972   Males       Senior           1.0            Liao Hui            CHN
# 19702  Males       Senior           1.0  Varbanov Alexander            BUL
# 19918  Males       Senior           1.0     Vardanyan Yurik            URS
# 26221  Males       Senior           1.0         Shi Zhiyong       Zhejiang
# 6100   Males       Senior           1.0          Chen Lijun            CHN
# 19155  Males       Senior           1.0    Khrapaty Anatoli            URS
# 5230   Males       Senior           1.0      Long Quingguan            CHN
#
#        Bodyweight (kg)  ... Snatch 2  Snatch 3  Snatch Rank  C&J 1  C&J 2  \
# 19283            59.70  ...    150.5     152.5          1.0  175.0  188.5
# 19664            59.80  ...      NaN       NaN          1.0  187.5    NaN
# 19728            82.30  ...      NaN       NaN          1.0  225.0    NaN
# 21075            81.70  ...    172.5     177.5          1.0  205.0  215.5
# 21248            81.70  ...    172.5     177.5          1.0  205.0  215.5
# 20679            81.80  ...      NaN       NaN          1.0  220.0    NaN
# 19427           109.55  ...    205.0     210.0          1.0  245.0  251.0
# 20500            89.55  ...      NaN       NaN          1.0  227.5    NaN
# 19565            89.60  ...      NaN       NaN          2.0  232.5    NaN
# 6849             68.68  ...    160.0     166.0          1.0  185.0  193.0
# 19773            99.60  ...      NaN       NaN          1.0  237.5    NaN
# 14576            68.78  ...    160.0     162.5          2.0  185.0  190.0
# 14998            68.65  ...    160.5     162.5          1.0  185.0  190.0
# 7972             68.52  ...    160.0     166.0          1.0  186.0  195.0
# 19702            74.65  ...      NaN       NaN          2.0  212.5    NaN
# 19918            81.95  ...      NaN       NaN          1.0  220.0    NaN
# 26221            68.80  ...    160.0     160.0          1.0  193.0  198.0
# 6100             61.89  ...    150.0     152.0          1.0  175.0  179.0
# 19155            89.40  ...    182.5     185.0          2.0  225.0  230.0
# 5230             55.68  ...    135.0     137.0          1.0  161.0  166.0
#
#        C&J 3  C&J Rank  Total (kg)  Sinclair  Sinclair (calculated)
# 19283  190.0       1.0       342.5       0.0             528.874967
# 19664    NaN       1.0       335.0       0.0             516.655165
# 19728    NaN       1.0       405.0       0.0             509.587669
# 21075  222.5       1.0       400.0       0.0             505.286624
# 21248  222.5       1.0       400.0       0.0             505.286624
# 20679    NaN       1.0       400.0       0.0             504.952189
# 19427  251.0       1.0       455.0       0.0             503.753757
# 20500    NaN       1.0       417.5       0.0             503.153733
# 19565    NaN       1.0       417.5       0.0             503.017853
# 6849     NaN       1.0       359.0     484.4             502.939595
# 19773    NaN       1.0       437.5       0.0             502.579235
# 14576  196.5       1.0       359.0     469.6             502.464053
# 14998  196.0       1.0       358.5     469.6             502.381939
# 7972   198.0       1.0       358.0     483.8             502.301165
# 19702    NaN       1.0       377.5       0.0             502.034044
# 19918    NaN       1.0       397.5       0.0             501.299774
# 26221  200.0       1.0       358.0     476.7             500.969804
# 6100   183.0       1.0       333.0     482.2             500.907423
# 19155  230.0       1.0       415.0       0.0             500.547298
# 5230   170.0       1.0       307.0     481.3             499.866756
#
# [20 rows x 22 columns]

# %% [markdown]
# This is looking fairly promising! It is not perfect, but it will work for our future analyses. The next step is EDA, and making sure that I can cross reference the table from before with positive results. It is probably worthwhile to set up a database now, so that cleaned data can be queried directly.

# %% [markdown]
# PROBLEM: To solve the issue of the column/series name, I think I can take the first or second (or both) rows and make them the column names. Then, once the names match, I can add them to the correct series that is (or will become) part of the data frame.
#
# SOLVED: 4/3/2024. Instead of the above solution, I forced the columns to have specific names. This required a try/except clause to make sure that I forced the correct number of columns onto each individual table. See the function all_data() for details.
