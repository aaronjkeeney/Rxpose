# %% [markdown]
# # RXposé (Version 2.0) #
#
# As of March, 2024, I greatly prefer working in Python over R. In this file, I will build a better pipeline than the version in R from last year, as well as (hopefully) incoroporate a better data source to be able to finish the original analysis. Ideally, this project will also produce a searchable database, allowing other contributors to perform future analysis.

# %% [markdown]
# ## Data Collection ##
#
# The first step is to collect better data. [This website](https://iwrp.net/) has results in PDF format going back to 1928. Since this format is not helpful for computer analysis, we need to scrape it and convert it to a .csv or similarly usable file.

# %%
# Imports for data collection
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

import re

import pandas as pd

# %%
# Write function to safely download PDF files from a given link

# This function is not useful anymore, but we will use it as a model for logic

def download_pdfs(url, save_directory):
    # Send GET request to URL
    response = requests.get(url)
    
    # Parse the HTML
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all links on the page to sort later
    links = soup.find_all('a')
    
    print(links)
    print(len(links))
    
    # Ensure directory is correctly set
    if  not os.path.exists(save_directory):
         os.makedirs(save_directory)
         
        
    # Loop through links, downloading only the PDFs
    for link in links[:5]:
        href = link.get('href')
        if href:
            # Make correct URL for GET request
            absolute_url = urljoin(url, href)
            
            linked_response = requests.get(absolute_url)
            
            linked_soup = BeautifulSoup(linked_response.content, 'html.parser')
            
            tables = linked_soup.find_all('table')
            
            filename = os.path.basename(absolute_url)
            
            with open(os.path.join(save_directory, filename), 'wb') as f:
                pdf_response = requests.get(absolute_url)
                f.write(pdf_response.content)
        
            print(f"Downloaded {filename} to {os.path}")

# %%
# Download files

download_pdfs('https://iwrp.net/', '/Users/aaronkeeney/Documents/Data_Analytics_Projects/Rxpose')
# Out:
# [<a href="/">IWRP</a>, <a href="/global-statistics">Global Statistics</a>, <a href="/../"><div class="header__logo"></div></a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2752">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2753">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2748">48 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2749">27 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2746">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2747">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2745">28 th Waldemar Malak Memorial	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2743">88 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2744">30 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2741">37th Asian JuniorChampionship</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2742">30 th Asian Junior Championship	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2737">Junior European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2738">Junior European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2739">Under 23 European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2740">Under 23 European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2733">Youth European Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2734">Youth European Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2735">Youth European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2736">Youth European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2729">93 rd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2730">30 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2731">55 th Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2732">31 st Polish Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2727">29 th Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2728">29 th Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2721">LZS - Youth Polish Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2722">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2723">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2724">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2714">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2715">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2716">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2717">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2718">Preliminary Junior Polish Championships - OOM	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2719">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2720">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2725">51 st Asian Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2726">31 st Asian Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2711">101 st E ...
# 2590
# */
# */global-statistics
# */../
# */component/cwyniki/?view=contest&id_zawody=2752
# */component/cwyniki/?view=contest&id_zawody=2753
# */component/cwyniki/?view=contest&id_zawody=2748
# */component/cwyniki/?view=contest&id_zawody=2749
# */component/cwyniki/?view=contest&id_zawody=2746
# */component/cwyniki/?view=contest&id_zawody=2747
# */component/cwyniki/?view=contest&id_zawody=2745
# */component/cwyniki/?view=contest&id_zawody=2743
# */component/cwyniki/?view=contest&id_zawody=2744
# */component/cwyniki/?view=contest&id_zawody=2741
# */component/cwyniki/?view=contest&id_zawody=2742
# */component/cwyniki/?view=contest&id_zawody=2737
# */component/cwyniki/?view=contest&id_zawody=2738
# */component/cwyniki/?view=contest&id_zawody=2739
# */component/cwyniki/?view=contest&id_zawody=2740
# */component/cwyniki/?view=contest&id_zawody=2733
# */component/cwyniki/?view=contest&id_zawody=2734

# %%
def download_table(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
    table = soup.find_all('table')
    
    
    if table:
        df = pd.read_html(str(table))[0]
        return df
        
    else:
        print(f"No table found on page")
        return None

# %%
df = download_table('https://iwrp.net/')
# Out:
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/291072501.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
print(df.head())
print(df.size)
# Out:
#          Date                              Name        Place Nation   Gender  \
# 0  2023-12-04                    IWF Grand Prix         Doha    QAT    Males
# 1  2023-12-04                    IWF Grand Prix         Doha    QAT  Females
# 2  2023-11-15  48 th Junior World Championships  Guadalajara    MEX    Males
# 3  2023-11-15  27 th Junior World Championships  Guadalajara    MEX  Females
# 4  2023-10-20  11 th Youth Polish Championships     Biłgoraj    POL    Males
#
#   Age category
# 0       Senior
# 1       Senior
# 2       Junior
# 3       Junior
# 4     Youth 15
# 15510

# %%
print(df[df['Gender'] == 'Males'].size)
print(df[df['Gender'] == 'Females'].size)
# Out:
# 6276
# 4656

# %%
df.dtypes
# Out:
# Date            object
# Name            object
# Place           object
# Nation          object
# Gender          object
# Age category    object
# dtype: object

# %%
def is_valid_date(date_string):
    try: 
        pd.to_datetime(date_string)
        return True
    except:
        ValueError
        return False

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/tools/datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "1979-00-00" doesn't match format "%Y-%m-%d", at position 983. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
valid_dates_mask = df['Date'].apply(is_valid_date)

invalid_dates = df[~valid_dates_mask]
invalid_dates
# Out:
#             Date                          Name  Place Nation Gender  \
# 2538  1979-00-00  57 th European Championships  Varna    BUL  Males
#
#      Age category
# 2538       Senior

# %%
# Quick internt search for the correct date

def replace_invalid_date(date_string):
    try: 
        pd.to_datetime(date_string)
        return date_string
    except:
        ValueError
        return '1979-05-19'
    
df['Date'] = df['Date'].apply(replace_invalid_date)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2585 entries, 0 to 2584
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2585 non-null   datetime64[ns]
#  1   Name          2585 non-null   object
#  2   Place         2583 non-null   object
#  3   Nation        2585 non-null   object
#  4   Gender        2585 non-null   object
#  5   Age category  2585 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 121.3+ KB

# %% [markdown]
# Okay, what I actually need to do for now:
#
# 1. I need to have a single dataframe with all the results, but I need the date included. I think I need to go back and get a datetime object instead of a numerical year. Then I can avoid duplicate rows, since a single lifter's total, name, and date of competition will be uniquely identifying. Not all of this data will be used in this analysis, but we want to be able to easily search for all international performances of any lifter.
#
# 2. I need to then retrieve the actual lifting information from the links. The smaller dataframe generated by importing the table(s) at each link can then be appended to the large dataframe. I NEED TO MAKE SURE THAT THE DATE AND THE WEIGHT CATEGORY ARE INCLUDED IN EACH ROW AS PART OF THIS TRANSFORMATION. This should be fairly simple. Create the data frame with the necessary columns, then populate all the scraped values as additional columns.

# %%
# Loop through the 'Name' column and follow the links

def download_links(url: str, events_list: list) -> pd.DataFrame:
    # Send GET request to URL
    response = requests.get(url)
    
    # Parse the HTML
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all links on the page to sort later
    links = soup.find_all('a')
    
    return [link for link in links]

# %%
links = download_links('https://iwrp.net/', df['Name'])
print(type(links))
# Out:
# <class 'list'>

# %%
print(links[:10])
print(len(links))
print(len(df['Name']))
# Out:
# [<a href="/">IWRP</a>, <a href="/global-statistics">Global Statistics</a>, <a href="/../"><div class="header__logo"></div></a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2752">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2753">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2748">48 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2749">27 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2746">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2747">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2745">28 th Waldemar Malak Memorial	</a>]
# 2590
# 2585

# %%
links = links[3:-2]
links[:10]
# Out:
# [<a href="/component/cwyniki/?view=contest&amp;id_zawody=2752">IWF Grand Prix</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2753">IWF Grand Prix</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2748">48 th Junior World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2749">27 th Junior World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2746">11 th Youth Polish Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2747">11 th Youth Polish Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2745">28 th Waldemar Malak Memorial	</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2743">88 th World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2744">30 th World Championships</a>,
#  <a href="/component/cwyniki/?view=contest&amp;id_zawody=2741">37th Asian JuniorChampionship</a>]

# %%
len(links)
# Out:
# 2585

# %%
print(links)
print(links[::-1])
# Out:
# [<a href="/component/cwyniki/?view=contest&amp;id_zawody=2752">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2753">IWF Grand Prix</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2748">48 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2749">27 th Junior World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2746">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2747">11 th Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2745">28 th Waldemar Malak Memorial	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2743">88 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2744">30 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2741">37th Asian JuniorChampionship</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2742">30 th Asian Junior Championship	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2737">Junior European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2738">Junior European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2739">Under 23 European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2740">Under 23 European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2733">Youth European Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2734">Youth European Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2735">Youth European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2736">Youth European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2729">93 rd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2730">30 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2731">55 th Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2732">31 st Polish Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2727">29 th Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2728">29 th Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2721">LZS - Youth Polish Championships	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2722">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2723">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2724">LZS - Youth Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2714">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2715">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2716">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2717">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2718">Preliminary Junior Polish Championships - OOM	</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2719">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2720">Preliminary Junior Polish Championships - OOM</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2725">51 st Asian Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2726">31 st Asian Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2711">101 st European Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2712">35 th European Championships</a>, <a h ...
# [<a href="/component/cwyniki/?view=contest&amp;id_zawody=24">IX Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=23">X Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=21">XI Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=19">XIV Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=17">XV Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=18">XVI Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2514">27 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2513">28 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2512">29 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2511">30 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=16">XVII Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2510">31 st Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2509">32 nd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1890">33 rd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1891">34 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=15">XVIII Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2538">39 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1904">35 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2543">40 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=1909">36 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2542">41 st World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2515">37 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2516">38 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=14">XIX Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2537">42 nd World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2517">39 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2541">43 rd World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2518">40 th Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2540">44 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=781">2 nd Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2519">41 st Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2539">45 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=782">3 rd  Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2520">42 nd Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=2536">46 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=327">XIX Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=77">47 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=76">48 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=783">6 th Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=75">49 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=784">7 th Under 23 Polish Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=74">50 th World Championships</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=12">XXI Olympics Games</a>, <a href="/component/cwyniki/?view=contest&amp;id_zawody=149 ...

# %%
df['link'] = str(links)
df.head()
# Out:
#         Date                              Name        Place Nation   Gender  \
# 0 2023-12-04                    IWF Grand Prix         Doha    QAT    Males
# 1 2023-12-04                    IWF Grand Prix         Doha    QAT  Females
# 2 2023-11-15  48 th Junior World Championships  Guadalajara    MEX    Males
# 3 2023-11-15  27 th Junior World Championships  Guadalajara    MEX  Females
# 4 2023-10-20  11 th Youth Polish Championships     Biłgoraj    POL    Males
#
#   Age category                                               link
# 0       Senior  [<a href="/component/cwyniki/?view=contest&amp...
# 1       Senior  [<a href="/component/cwyniki/?view=contest&amp...
# 2       Junior  [<a href="/component/cwyniki/?view=contest&amp...
# 3       Junior  [<a href="/component/cwyniki/?view=contest&amp...
# 4     Youth 15  [<a href="/component/cwyniki/?view=contest&amp...

# %%
def all_data(guiding_data_frame: pd.DataFrame) -> pd.DataFrame:
    pattern = re.compile(r'"([^"]*)"')
    for link in guiding_data_frame['link'][:1]:  # Consider removing [:2] for the full dataframe
        match = pattern.search(link)
        if match:
            event_link = match.group(1)
            absolute_url = 'https://iwrp.net/' + event_link

            response = requests.get(absolute_url)
            if response.status_code == 200:  # Check if request was successful
                soup = BeautifulSoup(response.content, 'html.parser')
                tables = soup.find_all('table')
                print(len(tables))
                for table in tables:
                    print(pd.read_html(str(table))[0])
                #weightclass_df = pd.read_html(str(table))[0]
                #print(weightclass_df.columns[1])
                
                    
                    # Do something with temp_df, such as concatenating it with another DataFrame
                    # Example: final_df = pd.concat([final_df, temp_df], ignore_index=True)
            else:
                print(f"Failed to fetch data from {absolute_url}. Status code: {response.status_code}")
        else:
            print(f"No match found for link: {link}")

# %%
all_data(df)
# Out:
# 10
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
#        55 kg                                                                \
#        61 kg
#        67 kg
#        73 kg
#        81 kg
#        89 kg
#        96 kg
#       102 kg
#       109 kg
#     + 109 kg                   + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0         Pl             Surname and name     Nation        B.W        Gr.
# 1         Pl             Surname and name     Nation        B.W        Gr.
# 2          1                 Pang Un Chol        PRK      54.94          A
# 3          2           Nugroho Satrio Adi        INA      54.79          A
# 4          3  Yodage Dilanka Isuru Kumara        SRI      55.00          A
# ..       ...                          ...        ...        ...        ...
# 213      NaN                 Minasyan Gor        ARM     150.00          B
# 214      NaN              Coullet Anthony        FRA     152.19          A
# 215      NaN       Sharifikelarijani Ayat        IRI     155.90          B
# 216      NaN   Djangabaev Jonibaev Rustan        UZB     165.50          B
# 217      NaN                  Davoudi Ali        IRI     180.00          B
#
#                                                                         \
#
#
#
#
#
#
#
#
#     + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0       Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1            1          2          3        NaN          1           2
# 2        110.0      114.0      116.0          1      142.0       148.0
# 3        108.0      112.0      115.0          2      135.0       139.0
# 4        106.0      112.0      114.0          4      133.0       139.0
# ..         ...        ...        ...        ...        ...         ...
# 213        ---        ---        ---        NaN        ---         ---
# 214        ---        ---        ---        NaN        ---         ---
# 215        ---        ---        ---        NaN        ---         ---
# 216        ---        ---        ---        NaN        ---         ---
# 217        ---        ---        ---        NaN        ---         ---
#
#
#
#
#
#
#
#
#
#
#     + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0       Cl&Jerk         NaN         NaN     Sincler
# 1             3         NaN         NaN     Sincler
# 2         152.0           1       268.0       441.0
# 3         144.0           2       254.0       418.9
# 4         140.0           3       245.0       402.8
# ..          ...         ...         ...         ...
# 213         ---         NaN         ---         0.0
# 214         ---         NaN         ---         0.0
# 215         ---         NaN         ---         0.0
# 216         ---         NaN         ---         0.0
# 217         ---         NaN         ---         0.0
#
# [218 rows x 15 columns]
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
#        61 kg                                                               \
#        67 kg
#        73 kg
#        81 kg
#        89 kg
#        96 kg
#       102 kg
#       109 kg
#     + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0         Pl            Surname and name     Nation        B.W        Gr.
# 1         Pl            Surname and name     Nation        B.W        Gr.
# 2          1               Pak Myong Jin        PRK      60.97          A
# 3          2          Ceniza John Fabuar        PHI      61.00          A
# 4          3     Bin Kasdan Mohamad Aniq        MAS      60.90          C
# ..       ...                         ...        ...        ...        ...
# 204      NaN                Minasyan Gor        ARM     150.00          B
# 205      NaN             Coullet Anthony        FRA     152.19          A
# 206      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 207      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 208      NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                         \
#
#
#
#
#
#
#
#     + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0       Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1            1          2          3        NaN          1           2
# 2        130.0      134.0      136.0          3      165.0       165.0
# 3        130.0      133.0      135.0          4      165.0       165.0
# 4        123.0      126.0      126.0          9      162.0       167.0
# ..         ...        ...        ...        ...        ...         ...
# 204        ---        ---        ---        NaN        ---         ---
# 205        ---        ---        ---        NaN        ---         ---
# 206        ---        ---        ---        NaN        ---         ---
# 207        ---        ---        ---        NaN        ---         ---
# 208        ---        ---        ---        NaN        ---         ---
#
#
#
#
#
#
#
#
#
#     + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0       Cl&Jerk         NaN         NaN     Sincler
# 1             3         NaN         NaN     Sincler
# 2         171.0           1       305.0       463.8
# 3         168.0           5       298.0       453.0
# 4         170.0           2       296.0       450.5
# ..          ...         ...         ...         ...
# 204         ---         NaN         ---         0.0
# 205         ---         NaN         ---         0.0
# 206         ---         NaN         ---         0.0
# 207         ---         NaN         ---         0.0
# 208         ---         NaN         ---         0.0
#
# [209 rows x 15 columns]
#        67 kg                                                               \
#        73 kg
#        81 kg
#        89 kg
#        96 kg
#       102 kg
#       109 kg
#     + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0         Pl            Surname and name     Nation        B.W        Gr.
# 1         Pl            Surname and name     Nation        B.W        Gr.
# 2          1                  RI Won\tJu        PRK      67.00          A
# 3          2                  Dimov Ivan        BUL      64.01          A
# 4          3             Rashidov Bunyad        TKM      66.67          A
# ..       ...                         ...        ...        ...        ...
# 178      NaN                Minasyan Gor        ARM     150.00          B
# 179      NaN             Coullet Anthony        FRA     152.19          A
# 180      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 181      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 182      NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                         \
#
#
#
#
#
#
#     + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0       Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1            1          2          3        NaN          1           2
# 2        133.0      136.0      139.0          3      168.0       175.0
# 3        134.0      137.0      140.0          2      155.0       160.0
# 4        138.0      141.0      144.0          1      157.0       161.0
# ..         ...        ...        ...        ...        ...         ...
# 178        ---        ---        ---        NaN        ---         ---
# 179        ---        ---        ---        NaN        ---         ---
# 180        ---        ---        ---        NaN        ---         ---
# 181        ---        ---        ---        NaN        ---         ---
# 182        ---        ---        ---        NaN        ---         ---
#
#
#
#
#
#
#
#
#     + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0       Cl&Jerk         NaN         NaN     Sincler
# 1             3         NaN         NaN     Sincler
# 2         178.0           1       317.0       451.4
# 3         165.0           5       300.0       440.7
# 4         161.0           7       298.0       425.8
# ..          ...         ...         ...         ...
# 178         ---         NaN         ---         0.0
# 179         ---         NaN         ---         0.0
# 180         ---         NaN         ---         0.0
# 181         ---         NaN         ---         0.0
# 182         ---         NaN         ---         0.0
#
# [183 rows x 15 columns]
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
#        73 kg                                                               \
#        81 kg
#        89 kg
#        96 kg
#       102 kg
#       109 kg
#     + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0         Pl            Surname and name     Nation        B.W        Gr.
# 1         Pl            Surname and name     Nation        B.W        Gr.
# 2          1            Suharevs Ritvars        LAT      73.00          A
# 3          2                 Shi Zhiyong        CHN      73.00          A
# 4          3           Wichuma Weeraphon        THA      73.00          A
# ..       ...                         ...        ...        ...        ...
# 161      NaN                Minasyan Gor        ARM     150.00          B
# 162      NaN             Coullet Anthony        FRA     152.19          A
# 163      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 164      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 165      NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                         \
#
#
#
#
#
#     + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0       Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1            1          2          3        NaN          1           2
# 2        150.0      154.0      156.0          2      175.0       180.0
# 3        155.0      160.0      163.0          1      180.0         ---
# 4        145.0      145.0        ---          7      182.0       187.0
# ..         ...        ...        ...        ...        ...         ...
# 161        ---        ---        ---        NaN        ---         ---
# 162        ---        ---        ---        NaN        ---         ---
# 163        ---        ---        ---        NaN        ---         ---
# 164        ---        ---        ---        NaN        ---         ---
# 165        ---        ---        ---        NaN        ---         ---
#
#
#
#
#
#
#
#     + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0       Cl&Jerk         NaN         NaN     Sincler
# 1             3         NaN         NaN     Sincler
# 2         185.0           3       341.0       459.7
# 3           ---           7       340.0       458.3
# 4         189.0           1       334.0       450.2
# ..          ...         ...         ...         ...
# 161         ---         NaN         ---         0.0
# 162         ---         NaN         ---         0.0
# 163         ---         NaN         ---         0.0
# 164         ---         NaN         ---         0.0
# 165         ---         NaN         ---         0.0
#
# [166 rows x 15 columns]
#        81 kg                                                               \
#        89 kg
#        96 kg
#       102 kg
#       109 kg
#     + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0         Pl            Surname and name     Nation        B.W        Gr.
# 1         Pl            Surname and name     Nation        B.W        Gr.
# 2          1                Ri Chongsong        PRK      78.00          A
# 3          2       Abdullah Rahmat Erwin        INA      76.93          A
# 4          3            Torayev Gaygysyz        TKM      80.73          A
# ..       ...                         ...        ...        ...        ...
# 134      NaN                Minasyan Gor        ARM     150.00          B
# 135      NaN             Coullet Anthony        FRA     152.19          A
# 136      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 137      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 138      NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                         \
#
#
#
#
#     + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0       Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1            1          2          3        NaN          1           2
# 2        160.0      160.0      165.0          1      200.0       206.0
# 3        153.0      157.0      161.0          2      192.0       201.0
# 4        145.0      145.0      150.0          6      186.0       188.0
# ..         ...        ...        ...        ...        ...         ...
# 134        ---        ---        ---        NaN        ---         ---
# 135        ---        ---        ---        NaN        ---         ---
# 136        ---        ---        ---        NaN        ---         ---
# 137        ---        ---        ---        NaN        ---         ---
# 138        ---        ---        ---        NaN        ---         ---
#
#
#
#
#
#
#     + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0       Cl&Jerk         NaN         NaN     Sincler
# 1             3         NaN         NaN     Sincler
# 2         209.0           1       374.0       484.8
# 3         214.0           2       362.0       473.0
# 4         193.0           3       338.0       429.8
# ..          ...         ...         ...         ...
# 134         ---         NaN         ---         0.0
# 135         ---         NaN         ---         0.0
# 136         ---         NaN         ---         0.0
# 137         ---         NaN         ---         0.0
# 138         ---         NaN         ---         0.0
#
# [139 rows x 15 columns]
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
#        89 kg                                                               \
#        96 kg
#       102 kg
#       109 kg
#     + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0         Pl            Surname and name     Nation        B.W        Gr.
# 1         Pl            Surname and name     Nation        B.W        Gr.
# 2          1                Nasar Karlos        BUL      88.02          A
# 3          2          Lopez Lopez Yeison        COL      88.98          A
# 4          3          Pizzolato Antonino        ITA      89.00          A
# ..       ...                         ...        ...        ...        ...
# 118      NaN                Minasyan Gor        ARM     150.00          B
# 119      NaN             Coullet Anthony        FRA     152.19          A
# 120      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 121      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 122      NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                         \
#
#
#
#     + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0       Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1            1          2          3        NaN          1           2
# 2        165.0      170.0      175.0          4      205.0       211.0
# 3        170.0      175.0      180.0          1      202.0       206.0
# 4        165.0      170.0      175.0          6      203.0       210.0
# ..         ...        ...        ...        ...        ...         ...
# 118        ---        ---        ---        NaN        ---         ---
# 119        ---        ---        ---        NaN        ---         ---
# 120        ---        ---        ---        NaN        ---         ---
# 121        ---        ---        ---        NaN        ---         ---
# 122        ---        ---        ---        NaN        ---         ---
#
#
#
#
#
#     + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0       Cl&Jerk         NaN         NaN     Sincler
# 1             3         NaN         NaN     Sincler
# 2         223.0           1       393.0       477.6
# 3         210.0           3       390.0       471.5
# 4         210.0           4       380.0       459.3
# ..          ...         ...         ...         ...
# 118         ---         NaN         ---         0.0
# 119         ---         NaN         ---         0.0
# 120         ---         NaN         ---         0.0
# 121         ---         NaN         ---         0.0
# 122         ---         NaN         ---         0.0
#
# [123 rows x 15 columns]
#       96 kg                                                               \
#      102 kg
#      109 kg
#    + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0        Pl            Surname and name     Nation        B.W        Gr.
# 1        Pl            Surname and name     Nation        B.W        Gr.
# 2         1       Matyakubov Shahzadbek        TKM      95.61          A
# 3         2          Hovhannisyan David        ARM      96.00          A
# 4         3               Yang Tae Bong        PRK      96.00          A
# ..      ...                         ...        ...        ...        ...
# 83      NaN                Minasyan Gor        ARM     150.00          B
# 84      NaN             Coullet Anthony        FRA     152.19          A
# 85      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 86      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 87      NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                        \
#
#
#    + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0      Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1           1          2          3        NaN          1           2
# 2       160.0      164.0      167.0          2      190.0       197.0
# 3       160.0      165.0      170.0          1      200.0       205.0
# 4       161.0      167.0      168.0          5      195.0       201.0
# ..        ...        ...        ...        ...        ...         ...
# 83        ---        ---        ---        NaN        ---         ---
# 84        ---        ---        ---        NaN        ---         ---
# 85        ---        ---        ---        NaN        ---         ---
# 86        ---        ---        ---        NaN        ---         ---
# 87        ---        ---        ---        NaN        ---         ---
#
#
#
#
#    + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0      Cl&Jerk         NaN         NaN     Sincler
# 1            3         NaN         NaN     Sincler
# 2        204.0           1       371.0       433.8
# 3        205.0           3       370.0       431.8
# 4        205.0           2       362.0       422.5
# ..         ...         ...         ...         ...
# 83         ---         NaN         ---         0.0
# 84         ---         NaN         ---         0.0
# 85         ---         NaN         ---         0.0
# 86         ---         NaN         ---         0.0
# 87         ---         NaN         ---         0.0
#
# [88 rows x 15 columns]
#      102 kg                                                               \
#      109 kg
#    + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0        Pl            Surname and name     Nation        B.W        Gr.
# 1        Pl            Surname and name     Nation        B.W        Gr.
# 2         1        Elbakh Fares Ibrahim        QAT     101.56          A
# 3         2                 Liu Huanhua        CHN     100.18          A
# 4         3            Karapetyan Garik        ARM     102.00          A
# ..      ...                         ...        ...        ...        ...
# 66      NaN                Minasyan Gor        ARM     150.00          B
# 67      NaN             Coullet Anthony        FRA     152.19          A
# 68      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 69      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 70      NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                        \
#
#    + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0      Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1           1          2          3        NaN          1           2
# 2       172.0      176.0      179.0          4      221.0       224.0
# 3       170.0      176.0      176.0          3      210.0       222.0
# 4       172.0      180.0      180.0          1      200.0       211.0
# ..        ...        ...        ...        ...        ...         ...
# 66        ---        ---        ---        NaN        ---         ---
# 67        ---        ---        ---        NaN        ---         ---
# 68        ---        ---        ---        NaN        ---         ---
# 69        ---        ---        ---        NaN        ---         ---
# 70        ---        ---        ---        NaN        ---         ---
#
#
#
#    + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0      Cl&Jerk         NaN         NaN     Sincler
# 1            3         NaN         NaN     Sincler
# 2        232.0           1       400.0       455.8
# 3        225.0           2       398.0       456.1
# 4        215.0           5       391.0       444.8
# ..         ...         ...         ...         ...
# 66         ---         NaN         ---         0.0
# 67         ---         NaN         ---         0.0
# 68         ---         NaN         ---         0.0
# 69         ---         NaN         ---         0.0
# 70         ---         NaN         ---         0.0
#
# [71 rows x 15 columns]
#       109 kg                                                               \
#     + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4
# 0         Pl            Surname and name     Nation        B.W        Gr.
# 1         Pl            Surname and name     Nation        B.W        Gr.
# 2          1          Dadashbayli Dadash        AZE     109.00          A
# 3          2        Rasulbekov Bekdoolot        KGZ     105.73          A
# 4          3   Rainibogi Taniela Tuisuva        FIJ     107.90          A
# 5          4              Kasabiev Arsen        POL     104.00          A
# 6          5          Martirosian Sargis        AUT     109.00          A
# 7          6               Meiram Sultan        KAZ     108.45          A
# 8          7              Sidiskis Arnas        LTU     108.91          A
# 9          8                 Ionita Paul        ROU     108.29          A
# 10         9                Skedelj Jure        SLO     107.70          A
# 11        10           Alruweai Mohammad        KUW     104.50          A
# 12       NaN                Karami Mehdi        IRI     107.06          A
# 13  + 109 kg                    + 109 kg   + 109 kg   + 109 kg   + 109 kg
# 14        Pl            Surname and name     Nation        B.W        Gr.
# 15        Pl            Surname and name     Nation        B.W        Gr.
# 16         1            Varazdat Lalayan        ARM     155.31          A
# 17         2           Martirosyan Simon        ARM     130.41          A
# 18         3            Ziaziulin Eduard        BLR     146.19          A
# 19         4            Murakami Eishiro        JPN     148.49          A
# 20         5                Kucera Kamil        CZE     154.34          A
# 21         6      Toychyyev Hojamuhammet        TKM     149.39          A
# 22         7                Wilkes Caine        USA     158.62          A
# 23         8         Michalski Arkadiusz        POL     115.93          B
# 24         9                  Nagy Peter        HUN     160.85          A
# 25        10               Chinen Kosuke        JPN     152.83          B
# 26        11                Bouamr Bilal        MAR     126.58          B
# 27        12               Gurdeep Singh        IND     161.13          B
# 28        13              Bhandari Sagar        NEP     122.62          B
# 29       NaN            Medina Alejandro        USA     123.04          A
# 30       NaN          Rubaiawi Ali Ammar        IRQ     129.35          B
# 31       NaN                  Mao Sanele        SAM     134.52          A
# 32       NaN                Holme Ragnar        NOR     137.12          B
# 33       NaN               Kajdoci Tamas        SRB     137.90          A
# 34       NaN                   Seim Mart        EST     148.87          B
# 35       NaN                Minasyan Gor        ARM     150.00          B
# 36       NaN             Coullet Anthony        FRA     152.19          A
# 37       NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 38       NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 39       NaN                 Davoudi Ali        IRI     180.00          B
#
#                                                                        \
#    + 109 kg.5 + 109 kg.6 + 109 kg.7 + 109 kg.8 + 109 kg.9 + 109 kg.10
# 0      Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 1           1          2          3        NaN          1           2
# 2       170.0      174.0      176.0          1      207.0       212.0
# 3       162.0      162.0      167.0          5      205.0       211.0
# 4       162.0      166.0      170.0          2      200.0       206.0
# 5       161.0      165.0      165.0          4      201.0       207.0
# 6       162.0      166.0      169.0          3      173.0       181.0
# 7       145.0      150.0      155.0          6      180.0       187.0
# 8       146.0      151.0      151.0          7      180.0       185.0
# 9       145.0      145.0      151.0          8      185.0       190.0
# 10      135.0      140.0      145.0          9      167.0       172.0
# 11      120.0      125.0      130.0         10      150.0       157.0
# 12        ---        ---        ---        NaN        ---         ---
# 13   + 109 kg   + 109 kg   + 109 kg   + 109 kg   + 109 kg    + 109 kg
# 14     Snatch     Snatch     Snatch        NaN    Cl&Jerk     Cl&Jerk
# 15          1          2          3        NaN          1           2
# 16      200.0      210.0      210.0          1      230.0       235.0
# 17      190.0      194.0        ---          3      231.0       240.0
# 18      180.0      187.0      193.0          2      220.0       225.0
# 19      180.0      185.0      188.0          4      220.0       225.0
# 20      172.0      172.0      180.0          7      216.0       221.0
# 21      168.0      174.0      179.0          5      212.0       217.0
# 22      168.0      171.0      180.0          8      203.0       213.0
# 23      160.0      165.0      170.0         11      200.0       210.0
# 24      160.0      167.0      171.0          9      201.0       211.0
# 25      150.0      150.0      160.0         13      190.0       200.0
# 26      153.0      153.0      160.0         14      190.0       193.0
# 27      135.0      145.0        ---         15      180.0       195.0
# 28      115.0      122.0      122.0         16      145.0       155.0
# 29      165.0      170.0      172.0         10      200.0       202.0
# 30        ---        ---        ---        NaN        ---         ---
# 31      172.0      180.0      180.0          6      220.0       220.0
# 32        ---        ---        ---        NaN        ---         ---
# 33      165.0      171.0      171.0         12      205.0       205.0
# 34        ---        ---        ---        NaN        ---         ---
# 35        ---        ---        ---        NaN        ---         ---
# 36        ---        ---        ---        NaN        ---         ---
# 37        ---        ---        ---        NaN        ---         ---
# 38        ---        ---        ---        NaN        ---         ---
# 39        ---        ---        ---        NaN        ---         ---
#
#
#    + 109 kg.11 + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0      Cl&Jerk         NaN         NaN     Sincler
# 1            3         NaN         NaN     Sincler
# 2        220.0           1       396.0       439.2
# 3        219.0           2       381.0       427.4
# 4        210.0           3       380.0       423.0
# 5        207.0           4       372.0       419.9
# 6          ---           8       347.0       384.9
# 7        191.0           5       346.0       384.5
# 8        190.0           7       341.0       378.3
# 9        196.0           6       335.0       372.4
# 10       176.0           9       312.0       347.6
# 11       164.0          10       289.0       325.6
# 12         ---         NaN         ---         0.0
# 13    + 109 kg    + 109 kg    + 109 kg    + 109 kg
# 14     Cl&Jerk         NaN         NaN     Sincler
# 15           3         NaN         NaN     Sincler
# 16       241.0           1       441.0       447.8
# 17         ---           2       430.0       451.6
# 18         ---           3       418.0       428.5
# 19       225.0           4       413.0       422.2
# 20       226.0           5       393.0       399.4
# 21       217.0           7       386.0       394.2
# 22       218.0           6       384.0       388.8
# 23         ---           8       375.0       407.3
# 24       217.0          10       372.0       376.0
# 25       210.0           9       370.0       376.6
# 26       195.0          12       343.0       363.0
# 27         ---          11       340.0       343.6
# 28       162.0          13       284.0       303.2
# 29       203.0         NaN         ---         0.0
# 30         ---         NaN         ---         0.0
# 31       220.0         NaN         ---         0.0
# 32         ---         NaN         ---         0.0
# 33       205.0         NaN         ---         0.0
# 34         ---         NaN         ---         0.0
# 35         ---         NaN         ---         0.0
# 36         ---         NaN         ---         0.0
# 37         ---         NaN         ---         0.0
# 38         ---         NaN         ---         0.0
# 39         ---         NaN         ---         0.0
#    + 109 kg                  + 109 kg.1 + 109 kg.2 + 109 kg.3 + 109 kg.4  \
# 0        Pl            Surname and name     Nation        B.W        Gr.
# 1        Pl            Surname and name     Nation        B.W        Gr.
# 2         1            Varazdat Lalayan        ARM     155.31          A
# 3         2           Martirosyan Simon        ARM     130.41          A
# 4         3            Ziaziulin Eduard        BLR     146.19          A
# 5         4            Murakami Eishiro        JPN     148.49          A
# 6         5                Kucera Kamil        CZE     154.34          A
# 7         6      Toychyyev Hojamuhammet        TKM     149.39          A
# 8         7                Wilkes Caine        USA     158.62          A
# 9         8         Michalski Arkadiusz        POL     115.93          B
# 10        9                  Nagy Peter        HUN     160.85          A
# 11       10               Chinen Kosuke        JPN     152.83          B
# 12       11                Bouamr Bilal        MAR     126.58          B
# 13       12               Gurdeep Singh        IND     161.13          B
# 14       13              Bhandari Sagar        NEP     122.62          B
# 15      NaN            Medina Alejandro        USA     123.04          A
# 16      NaN          Rubaiawi Ali Ammar        IRQ     129.35          B
# 17      NaN                  Mao Sanele        SAM     134.52          A
# 18      NaN                Holme Ragnar        NOR     137.12          B
# 19      NaN               Kajdoci Tamas        SRB     137.90          A
# 20      NaN                   Seim Mart        EST     148.87          B
# 21      NaN                Minasyan Gor        ARM     150.00          B
# 22      NaN             Coullet Anthony        FRA     152.19          A
# 23      NaN      Sharifikelarijani Ayat        IRI     155.90          B
# 24      NaN  Djangabaev Jonibaev Rustan        UZB     165.50          B
# 25      NaN                 Davoudi Ali        IRI     180.00          B
#
#    + 109 kg.5 + 109 kg.6 + 109 kg.7  + 109 kg.8 + 109 kg.9 + 109 kg.10  \
# 0      Snatch     Snatch     Snatch         NaN    Cl&Jerk     Cl&Jerk
# 1           1          2          3         NaN          1           2
# 2       200.0      210.0      210.0         1.0      230.0       235.0
# 3       190.0      194.0        ---         3.0      231.0       240.0
# 4       180.0      187.0      193.0         2.0      220.0       225.0
# 5       180.0      185.0      188.0         4.0      220.0       225.0
# 6       172.0      172.0      180.0         7.0      216.0       221.0
# 7       168.0      174.0      179.0         5.0      212.0       217.0
# 8       168.0      171.0      180.0         8.0      203.0       213.0
# 9       160.0      165.0      170.0        11.0      200.0       210.0
# 10      160.0      167.0      171.0         9.0      201.0       211.0
# 11      150.0      150.0      160.0        13.0      190.0       200.0
# 12      153.0      153.0      160.0        14.0      190.0       193.0
# 13      135.0      145.0        ---        15.0      180.0       195.0
# 14      115.0      122.0      122.0        16.0      145.0       155.0
# 15      165.0      170.0      172.0        10.0      200.0       202.0
# 16        ---        ---        ---         NaN        ---         ---
# 17      172.0      180.0      180.0         6.0      220.0       220.0
# 18        ---        ---        ---         NaN        ---         ---
# 19      165.0      171.0      171.0        12.0      205.0       205.0
# 20        ---        ---        ---         NaN        ---         ---
# 21        ---        ---        ---         NaN        ---         ---
# 22        ---        ---        ---         NaN        ---         ---
# 23        ---        ---        ---         NaN        ---         ---
# 24        ---        ---        ---         NaN        ---         ---
# 25        ---        ---        ---         NaN        ---         ---
#
#    + 109 kg.11  + 109 kg.12 + 109 kg.13 + 109 kg.14
# 0      Cl&Jerk          NaN         NaN     Sincler
# 1            3          NaN         NaN     Sincler
# 2        241.0          1.0       441.0       447.8
# 3          ---          2.0       430.0       451.6
# 4          ---          3.0       418.0       428.5
# 5        225.0          4.0       413.0       422.2
# 6        226.0          5.0       393.0       399.4
# 7        217.0          7.0       386.0       394.2
# 8        218.0          6.0       384.0       388.8
# 9          ---          8.0       375.0       407.3
# 10       217.0         10.0       372.0       376.0
# 11       210.0          9.0       370.0       376.6
# 12       195.0         12.0       343.0       363.0
# 13         ---         11.0       340.0       343.6
# 14       162.0         13.0       284.0       303.2
# 15       203.0          NaN         ---         0.0
# 16         ---          NaN         ---         0.0
# 17       220.0          NaN         ---         0.0
# 18         ---          NaN         ---         0.0
# 19       205.0          NaN         ---         0.0
# 20         ---          NaN         ---         0.0
# 21         ---          NaN         ---         0.0
# 22         ---          NaN         ---         0.0
# 23         ---          NaN         ---         0.0
# 24         ---          NaN         ---         0.0
# 25         ---          NaN         ---         0.0
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])
# /var/folders/84/dwt352cn4p74lsf57dxx96b00000gn/T/ipykernel_21617/3769566997.py:15: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   print(pd.read_html(str(table))[0])

# %% [markdown]
# Something odd about how these tables are constructed...somehow, the list of weightclasses is being interpreted as the column names. I don't know if there is a way to fix this directly. I would like to ignore those labels, since bodyweight and sinclair are already calculated for me...
#
# With that in mind, it appears that all relevant information is in the first table. This means that I can likely just take the first table from each page?
#
# I emailed the owner to ask for access to their data for this project. Going to pause here and wait for a bit.
